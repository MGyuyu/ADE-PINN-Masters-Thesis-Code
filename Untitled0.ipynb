# %% [markdown]
# <a href="https://colab.research.google.com/github/MGyuyu/ADE-PINN-Masters-Thesis-Code/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyDOE
# Out:
# Collecting pyDOE
#   Downloading pyDOE-0.3.8.zip (22 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pyDOE) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pyDOE) (1.14.1)
# Building wheels for collected packages: pyDOE
#   Building wheel for pyDOE (setup.py) ... done
#   Created wheel for pyDOE: filename=pyDOE-0.3.8-py3-none-any.whl size=18170 sha256=1fb05f5997afda13864d718931a87d3c4f2c4912cce0d2877b802633dbb500cd
#   Stored in directory: /root/.cache/pip/wheels/84/20/8c/8bd43ba42b0b6d39ace1219d6da1576e0dac81b12265c4762e
# Successfully built pyDOE
# Installing collected packages: pyDOE
# Successfully installed pyDOE-0.3.8

# %%
import sys
import os
import time
from datetime import datetime
import tensorflow as tf
import numpy as np
import scipy.io
import tensorflow_probability as tfp
from pyDOE import lhs

import matplotlib
from scipy.io import savemat
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from scipy.interpolate import griddata
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# LBFGS回调全局变量
callback_lbfgs_iterations = []
callback_lbfgs_losses = []
callback_lbfgs_l1s = []
callback_lbfgs_l2s = []

def dot(a, b):
  """Dot product function since TensorFlow doesn't have one."""
  return tf.reduce_sum(a*b)

def verbose_func(s):
  print(s)

final_loss = None
times = []
def lbfgs(opfunc, x, state, maxIter=100, learningRate=1, do_verbose=True, callback=None):
  """port of lbfgs.lua, using TensorFlow eager mode.
  """

  global final_loss, times, callback_lbfgs_iterations, callback_lbfgs_losses, callback_lbfgs_l1s, callback_lbfgs_l2s

  # 清空全局回调变量
  callback_lbfgs_iterations = []
  callback_lbfgs_losses = []
  callback_lbfgs_l1s = []
  callback_lbfgs_l2s = []

  maxEval = maxIter*1.25
  tolFun = 1e-5
  tolX = 1e-9
  nCorrection = 50
  isverbose = False

  # verbose function
  if isverbose:
    verbose = verbose_func
  else:
    verbose = lambda x: None

  f, g = opfunc(x)

  # 初始回调
  if callback is not None:
    callback_lbfgs_iterations.append(0)
    callback_lbfgs_losses.append(f.numpy())
    callback(x)

  f_hist = [f]
  currentFuncEval = 1
  state.funcEval = state.funcEval + 1
  p = g.shape[0]

  # check optimality of initial point
  tmp1 = tf.abs(g)
  if tf.reduce_sum(tmp1) <= tolFun:
    verbose("optimality condition below tolFun")
    return x, f_hist

  # optimize for a max of maxIter iterations
  nIter = 0
  times = []
  while nIter < maxIter:
    start_time = time.time()

    # keep track of nb of iterations
    nIter = nIter + 1
    state.nIter = state.nIter + 1

    ############################################################
    ## compute gradient descent direction
    ############################################################
    if state.nIter == 1:
      d = -g
      old_dirs = []
      old_stps = []
      Hdiag = 1
    else:
      # do lbfgs update (update memory)
      y = g - g_old
      s = d*t
      ys = dot(y, s)

      if ys > 1e-10:
        # updating memory
        if len(old_dirs) == nCorrection:
          # shift history by one (limited-memory)
          del old_dirs[0]
          del old_stps[0]

        # store new direction/step
        old_dirs.append(s)
        old_stps.append(y)

        # update scale of initial Hessian approximation
        Hdiag = ys/dot(y, y)

      # compute the approximate (L-BFGS) inverse Hessian
      # multiplied by the gradient
      k = len(old_dirs)

      # need to be accessed element-by-element, so don't re-type tensor:
      ro = [0]*nCorrection
      for i in range(k):
        ro[i] = 1/dot(old_stps[i], old_dirs[i])


      # iteration in L-BFGS loop collapsed to use just one buffer
      # need to be accessed element-by-element, so don't re-type tensor:
      al = [0]*nCorrection

      q = -g
      for i in range(k-1, -1, -1):
        al[i] = dot(old_dirs[i], q) * ro[i]
        q = q - al[i]*old_stps[i]

      # multiply by initial Hessian
      r = q*Hdiag
      for i in range(k):
        be_i = dot(old_stps[i], r) * ro[i]
        r += (al[i]-be_i)*old_dirs[i]

      d = r
      # final direction is in r/d (same object)

    g_old = g
    f_old = f

    ############################################################
    ## compute step length
    ############################################################
    # directional derivative
    gtd = dot(g, d)

    # check that progress can be made along that direction
    if gtd > -tolX:
      verbose("Can not make progress along direction.")
      break

    # reset initial guess for step size
    if state.nIter == 1:
      tmp1 = tf.abs(g)
      t = min(1, 1/tf.reduce_sum(tmp1))
    else:
      t = learningRate

    x += t*d

    if nIter != maxIter:
      # re-evaluate function only if not in last iteration
      # the reason we do this: in a stochastic setting,
      # no use to re-evaluate that function here
      f, g = opfunc(x)

    lsFuncEval = 1
    f_hist.append(f)

    # 在每次迭代后调用回调函数
    if callback is not None:
      callback_lbfgs_iterations.append(nIter)
      callback_lbfgs_losses.append(f.numpy())
      callback(x)

    # update func eval
    currentFuncEval = currentFuncEval + lsFuncEval
    state.funcEval = state.funcEval + lsFuncEval

    ############################################################
    ## check conditions
    ############################################################
    if nIter == maxIter:
      break

    if currentFuncEval >= maxEval:
      # max nb of function evals
      print('max nb of function evals')
      break

    tmp1 = tf.abs(g)
    if tf.reduce_sum(tmp1) <=tolFun:
      # check optimality
      print('optimality condition below tolFun')
      break

    tmp1 = tf.abs(d*t)
    if tf.reduce_sum(tmp1) <= tolX:
      # step size below tolX
      print('step size below tolX')
      break

    if tf.abs(f,f_old) < tolX:
      # function value changing less than tolX
      print('function value changing less than tolX'+str(tf.abs(f-f_old)))
      break

    if do_verbose:
      if nIter % 10 == 0:
        print("Step %3d loss %6.5f "%(nIter, f.numpy()))


    if nIter == maxIter - 1:
      final_loss = f.numpy()


  # save state
  state.old_dirs = old_dirs
  state.old_stps = old_stps
  state.Hdiag = Hdiag
  state.g_old = g_old
  state.f_old = f_old
  state.t = t
  state.d = d

  return x, f_hist, currentFuncEval

# dummy/Struct gives Lua-like struct object with 0 defaults
class dummy(object):
  pass

class Struct(dummy):
  def __getattribute__(self, key):
    if key == '__dict__':
      return super(dummy, self).__getattribute__('__dict__')
    return self.__dict__.get(key, 0)


def prep_data_dense(path, N_u, noise, inc_bounds, ICBC):
    """准备PINN反演的数据"""
    data = scipy.io.loadmat(path)

    # Flatten makes [[]] into [], [:,None] makes it a column vector
    t = data['t'].flatten()[:,None] # T x 1
    x = data['x'].flatten()[:,None] # N x 1

    # Keeping the 2D data for the solution data
    Exact_u = np.real(data['u']) # T x N  (注意这里不进行转置)

    # Meshing x and t in 2D (256,100)
    X, T = np.meshgrid(x,t)

    # Preparing the inputs x and t (meshed as X, T) for predictions in one single array
    X_star = np.hstack((X.flatten()[:,None], T.flatten()[:,None]))

    # Preparing the testing u_star
    u_star = Exact_u.flatten()[:,None]

    # 随机选择内部点
    idx = np.random.choice(X_star.shape[0], N_u, replace=False)
    X_u_train = X_star[idx,:]
    u_train = u_star[idx,:]

    # 添加噪声
    u_train = u_train + noise*np.std(u_train)*np.random.randn(u_train.shape[0], u_train.shape[1])
    u_star = u_star + noise*np.std(u_star)*np.random.randn(u_star.shape[0], u_star.shape[1])

    # 如果需要包含边界条件
    if inc_bounds == True:
        # 获取初始条件(t=0)
        xx1 = np.hstack((X[0:1,:].flatten()[:,None], T[0:1,:].flatten()[:,None]))
        uu1 = Exact_u[0:1,:].flatten()[:,None]
        # 获取左边界条件(x=-1)
        xx2 = np.hstack((X[:,0:1].flatten()[:,None], T[:,0:1].flatten()[:,None]))
        uu2 = Exact_u[:,0:1].flatten()[:,None]
        # 获取右边界条件(x=1)
        xx3 = np.hstack((X[:,-1:].flatten()[:,None], T[:,-1:].flatten()[:,None]))
        uu3 = Exact_u[:,-1:].flatten()[:,None]

        # 堆叠边界条件
        X_u_bounds = np.vstack([xx1, xx2, xx3])
        u_bounds = np.vstack([uu1, uu2, uu3])

        # 从边界条件中随机选择ICBC个点
        size = X_u_bounds.shape[0]
        samples = int(ICBC)
        rnd_bounds = np.random.choice(size, samples, replace=False)
        X_u_bounds = X_u_bounds[rnd_bounds,:]
        u_bounds = u_bounds[rnd_bounds,:]

        # 将边界条件点添加到训练数据
        X_u_train = np.vstack([X_u_train, X_u_bounds])
        u_train = np.vstack([u_train, u_bounds])

    # 计算边界
    lb = X_star.min(axis=0)
    ub = X_star.max(axis=0)

    return x, t, X, T, X_star, u_star, X_u_train, u_train, ub, lb


def TrainingDataPlotter(X_u_train, ub, lb):
    """可视化训练数据点"""
    fig = plt.figure()
    ax = fig.add_subplot()

    ax.scatter(X_u_train[:,1], X_u_train[:,0], s=4.0, marker='o', alpha=1.0)

    ax.set_xlabel('t')
    ax.set_ylabel('x')
    ax.set_xlim(lb[1]-0.1, ub[1]+0.1)
    ax.set_ylim(lb[0]-0.1, ub[0]+0.1)

    plt.show()

    print('Amount of training data: ' + str(X_u_train.shape[0]))


def LossParameterPlotter(loss_history, l1_history, l2_history):
    """绘制损失和参数历史"""
    # 确保所有历史记录长度一致
    min_len = min(len(loss_history), len(l1_history), len(l2_history))
    loss_history = loss_history[:min_len]
    l1_history = l1_history[:min_len]
    l2_history = l2_history[:min_len]

    fig, axes = plt.subplots(2, sharex=True, figsize=(12, 12))
    fig.suptitle('Training Metrics')

    axes[0].set_ylabel("Loss", fontsize=14)
    axes[0].set_xlabel("Epoch", fontsize=14)
    axes[0].semilogy(loss_history)

    axes[1].set_ylabel("l1,l2", fontsize=14)
    axes[1].set_xlabel("Epoch", fontsize=14)
    axes[1].plot(l1_history, label='l1 (position)')
    axes[1].plot(l2_history, label='l2 (strength)')

    # 添加真实值参考线
    if 'lambdas_star' in globals():
        axes[1].hlines(lambdas_star[0], 0, len(l1_history), linestyles='dashed', label='True l1')
        axes[1].hlines(lambdas_star[1], 0, len(l2_history), linestyles='dashed', label='True l2')

    axes[1].legend()
    plt.show()


def DiscretePlotter(x, t, u_plot, u_star_plot, lb, ub):
    """绘制不同时间点的解决方案"""
    def figsize(scale, nplots=1):
        fig_width_pt = 390.0
        inches_per_pt = 1.0/72.27
        golden_mean = (np.sqrt(5.0)-1.0)/2.0
        fig_width = fig_width_pt*inches_per_pt*scale
        fig_height = nplots*fig_width*golden_mean
        fig_size = [fig_width, fig_height]
        return fig_size

    def newfig(width, nplots=1):
        fig = plt.figure(figsize=figsize(width, nplots))
        ax = fig.add_subplot(111)
        return fig, ax

    N_t = t.shape[0]
    Lt = ub[1] - lb[1]
    t0 = 0; t1 = Lt/5; t2 = 2*Lt/5; t3 = 3*Lt/5; t4 = 4*Lt/5; t5 = 5*Lt/5;
    N0 = int(np.ceil((t0*N_t)/Lt))
    N1 = int(np.ceil((t1*N_t)/Lt))
    N2 = int(np.ceil((t2*N_t)/Lt))
    N3 = int(np.ceil((t3*N_t)/Lt))
    N4 = int(np.ceil((t4*N_t)/Lt))
    N5 = int(np.floor((t5*N_t-1)/Lt))

    fig, ax = newfig(3.0, 3.0)
    gs1 = gridspec.GridSpec(2, 3)
    gs1.update(top=1-1.0/3.0-0.1, bottom=1.0-2.0/3.0, left=0.1, right=0.9, wspace=0.5)

    ax = plt.subplot(gs1[0, 0])
    ax.plot(x, u_star_plot[:,N0], 'b-', linewidth=2, label='Exact')
    ax.plot(x, u_plot[:,N0], 'r--', linewidth=2, label='Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')
    ax.set_title('$t = 0.0$', fontsize=10)
    ax.axis('square')
    ax.set_xlim([-1.1, 1.1])
    ax.set_ylim([-1.1, 1.1])

    ax = plt.subplot(gs1[0, 1])
    ax.plot(x, u_star_plot[:,N1], 'b-', linewidth=2, label='Exact')
    ax.plot(x, u_plot[:,N1], 'r--', linewidth=2, label='Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')
    ax.set_title('$t = 0.2$', fontsize=10)
    ax.axis('square')
    ax.set_xlim([-1.1, 1.1])
    ax.set_ylim([-1.1, 1.1])

    ax = plt.subplot(gs1[0, 2])
    ax.plot(x, u_star_plot[:,N2], 'b-', linewidth=2, label='Exact')
    ax.plot(x, u_plot[:,N2], 'r--', linewidth=2, label='Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')
    ax.set_title('$t = 0.4$', fontsize=10)
    ax.axis('square')
    ax.set_xlim([-1.1, 1.1])
    ax.set_ylim([-1.1, 1.1])

    ax = plt.subplot(gs1[1, 0])
    ax.plot(x, u_star_plot[:,N3], 'b-', linewidth=2, label='Exact')
    ax.plot(x, u_plot[:,N3], 'r--', linewidth=2, label='Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')
    ax.set_title('$t = 0.6$', fontsize=10)
    ax.axis('square')
    ax.set_xlim([-1.1, 1.1])
    ax.set_ylim([-1.1, 1.1])

    ax = plt.subplot(gs1[1, 1])
    ax.plot(x, u_star_plot[:,N4], 'b-', linewidth=2, label='Exact')
    ax.plot(x, u_plot[:,N4], 'r--', linewidth=2, label='Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')
    ax.set_title('$t = 0.8$', fontsize=10)
    ax.axis('square')
    ax.set_xlim([-1.1, 1.1])
    ax.set_ylim([-1.1, 1.1])

    ax = plt.subplot(gs1[1, 2])
    ax.plot(x, u_star_plot[:,N5], 'b-', linewidth=2, label='Exact')
    ax.plot(x, u_plot[:,N5], 'r--', linewidth=2, label='Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')
    ax.set_title('$t = 1.0$', fontsize=10)
    ax.axis('square')
    ax.set_xlim([-1.1, 1.1])
    ax.set_ylim([-1.1, 1.1])
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.35), ncol=5, frameon=False)
    plt.show()


def ExtractData(pinn, X_star, X_u_train, u_star):
    """从训练好的PINN提取数据"""
    # 对密集网格进行预测
    X_star_batches = np.array_split(X_star, 100)
    u_pred, _ = pinn.predict(X_star_batches[0])
    for i in range(len(X_star_batches)-1):
        u_pred_batch, _ = pinn.predict(X_star_batches[i+1])
        u_pred = np.vstack((u_pred, u_pred_batch))

    # 对训练点进行预测
    X_u_train_batches = np.array_split(X_u_train, 100)
    u_train_pred, _ = pinn.predict(X_u_train_batches[0])
    for i in range(len(X_u_train_batches)-1):
        u_train_batch, _ = pinn.predict(X_u_train_batches[i+1])
        u_train_pred = np.vstack((u_train_pred, u_train_batch))

    u_train_pred = u_train_pred.flatten()[:,None]

    N_x = x.shape[0]
    N_t = t.shape[0]

    # 重塑为网格形式
    u_plot = u_pred.reshape(N_t, N_x).T
    u_star_plot = u_star.reshape(N_t, N_x).T

    # 获取训练权重
    trained_weights = pinn.get_weights()

    return u_star_plot, u_plot, u_train_pred, trained_weights


class Logger(object):
    """日志记录器"""
    def __init__(self, frequency=10):
        print("TensorFlow version: {}".format(tf.__version__))
        print("Eager execution: {}".format(tf.executing_eagerly()))
        print("GPU-accerelated: {}".format(tf.test.is_gpu_available()))

        self.start_time = time.time()
        self.frequency = frequency

    def __get_elapsed(self):
        return datetime.fromtimestamp(time.time() - self.start_time).strftime("%H:%M:%S")

    def __get_error_u(self):
        return self.error_fn()

    def set_error_fn(self, error_fn):
        self.error_fn = error_fn

    def log_train_start(self, model):
        print("\nTraining started")
        print("================")
        self.model = model
        print(self.model.summary())

    def log_train_epoch(self, epoch, loss, current_best_loss, custom=""):
        if epoch % self.frequency == 0:
            print(f"{'tf_epoch'} = {epoch:6d}  elapsed = {self.__get_elapsed()}  loss = {loss:.4e}  best loss = {current_best_loss:.4e}  error = {self.__get_error_u():.4e}  " + custom)

    def log_train_opt(self, name):
        print(f"—— Starting {name} optimization ——")

    def log_train_end(self, epoch, loss, current_best_loss, custom=""):
        print("==================")
        print(f"Training finished (epoch {epoch}): duration = {self.__get_elapsed()}  loss = {loss:.4e}  best loss = {current_best_loss:.4e}  error = {self.__get_error_u():.4e}  " + custom)
        print('Applying the weights at the best epoch to the model...')


class PhysicsInformedNN(object):
    """物理信息神经网络反演模型"""
    def __init__(self, layers, optimizer, logger, ub, lb, f_param, u_param, activation_func=tf.keras.activations.tanh):
        # 建立神经网络模型 [2, 20, …, 20, 1]
        self.u_model = tf.keras.Sequential()
        self.u_model.add(tf.keras.layers.InputLayer(input_shape=(layers[0],)))
        self.u_model.add(tf.keras.layers.Lambda(
            lambda X: 2.0*(X - lb)/(ub - lb) - 1.0))
        for width in layers[1:-1]:
            self.u_model.add(tf.keras.layers.Dense(
                width, activation=activation_func,
                kernel_initializer='glorot_normal'))
        self.u_model.add(tf.keras.layers.Dense(
                layers[-1], activation=None,
                kernel_initializer='glorot_normal'))

        self.dtype = tf.float32
        self.loss_history = []
        self.l1_history = []
        self.l2_history = []
        self.f_param = f_param
        self.u_param = u_param
        self.current_best_loss = 1e10
        self.current_best_weights = []

        # 定义用于识别的两个可训练变量
        self.lambda_1 = tf.Variable([0.0], dtype=self.dtype)  # 源项位置
        self.lambda_2 = tf.Variable([2.0], dtype=self.dtype)  # 源项强度

        # 计算权重/偏置的大小，用于后续分解
        self.sizes_w = []
        self.sizes_b = []
        for i, width in enumerate(layers):
            if i != 1:
                self.sizes_w.append(int(width * layers[1]))
                self.sizes_b.append(int(width if i != 0 else layers[1]))

        self.optimizer = optimizer
        self.logger = logger

        self.beta = 0.1  # 自适应权重参数
        self.adaptive_param = 1.0
        self.adaptive_param_hat = 1.0
        self.adaptive_param_history = []

    # 物理模型 - PDE实现
    def __f_model(self, X_f):
        l1, l2 = self.get_params()
        # 分离坐标
        x_f = tf.convert_to_tensor(X_f[:, 0:1], dtype=self.dtype)
        t_f = tf.convert_to_tensor(X_f[:, 1:2], dtype=self.dtype)

        # 使用TF2.0的GradientTape计算导数
        with tf.GradientTape(persistent=True) as tape:
            tape.watch(x_f)
            tape.watch(t_f)
            X_f = tf.stack([x_f[:,0], t_f[:,0]], axis=1)

            # 获取预测
            u = self.u_model(X_f)
            # 计算空间一阶导数
            u_x = tape.gradient(u, x_f)

        # 计算其他导数
        u_xx = tape.gradient(u_x, x_f)  # 空间二阶导数
        u_t = tape.gradient(u, t_f)  # 时间导数

        del tape

        # 对流扩散方程 + 源项
        PDE = u_t + 1.0*u_x - (0.25/np.pi)*u_xx - l2*tf.exp(-100*(x_f-l1)**2)
        return PDE

    # 损失函数计算
    def __loss(self, X_u, u, u_pred):
        f_pred = self.__f_model(X_u)
        loss_f = tf.reduce_mean(tf.square(f_pred))  # PDE残差损失
        loss_u = tf.reduce_mean(tf.square(u - u_pred))  # 数据拟合损失
        return loss_u, loss_f

    # 梯度计算
    def __grad(self, X_u, u):
        with tf.GradientTape() as tape:
            loss_u, loss_f = self.__loss(X_u, u, self.u_model(X_u))
            loss_value = self.adaptive_param*loss_u + 1.0*loss_f
        return loss_value, tape.gradient(loss_value, self.__wrap_training_variables())

    # 自适应权重更新
    def __adaptive_param(self, X_u, u):
        with tf.GradientTape(persistent=True) as tape:
            loss_u, loss_f = self.__loss(X_u, u, self.u_model(X_u))
            grad_u = tape.gradient(self.adaptive_param*loss_u, self.u_model.trainable_variables)
            grad_f = tape.gradient(loss_f, self.__wrap_training_variables())
        del tape

        grad_f_flatten = []
        grad_u_flatten = []
        for g in grad_f:
            if g is not None:
                grad_f_flatten.append(tf.reshape(g, [-1]))
        grad_f_flatten = tf.concat(grad_f_flatten, 0)

        for g in grad_u:
            if g is not None:
                grad_u_flatten.append(tf.reshape(g, [-1]))
        grad_u_flatten = tf.concat(grad_u_flatten, 0)

        max_grad_f = tf.reduce_max(tf.abs(grad_f_flatten))
        mean_grad_u = tf.reduce_mean(tf.abs(grad_u_flatten))

        # 防止除零
        if mean_grad_u == 0:
            self.adaptive_param_hat = 1.0
        else:
            self.adaptive_param_hat = max_grad_f / mean_grad_u

        # 平滑更新
        self.adaptive_param = self.adaptive_param * (1.0 - self.beta) + self.beta * self.adaptive_param_hat
        self.adaptive_param_history.append(self.adaptive_param)

    # 获取所有训练变量
    def __wrap_training_variables(self):
        var = self.u_model.trainable_variables
        var.extend([self.lambda_1, self.lambda_2])
        return var

    # 为L-BFGS优化准备函数
    def get_loss_and_flat_grad(self, X_u, u):
        def loss_and_flat_grad(w):
            with tf.GradientTape() as tape:
                self.set_weights(w)
                loss_u, loss_f = self.__loss(X_u, u, self.u_model(X_u))
                loss_value = self.adaptive_param*loss_u + 1.0*loss_f
            grad = tape.gradient(loss_value, self.__wrap_training_variables())
            grad_flat = []
            for g in grad:
                if g is not None:
                    grad_flat.append(tf.reshape(g, [-1]))
            grad_flat = tf.concat(grad_flat, 0)
            return loss_value, grad_flat
        return loss_and_flat_grad

    # 获取模型权重
    def get_weights(self):
        w = []
        for layer in self.u_model.layers[1:]:
            weights_biases = layer.get_weights()
            weights = weights_biases[0].flatten()
            biases = weights_biases[1]
            w.extend(weights)
            w.extend(biases)
        w.extend(self.lambda_1.numpy())
        w.extend(self.lambda_2.numpy())
        return tf.convert_to_tensor(w, dtype=self.dtype)

    # 设置模型权重
    def set_weights(self, w):
        for i, layer in enumerate(self.u_model.layers[1:]):
            start_weights = sum(self.sizes_w[:i]) + sum(self.sizes_b[:i])
            end_weights = sum(self.sizes_w[:i+1]) + sum(self.sizes_b[:i])
            weights = w[start_weights:end_weights]
            w_div = int(self.sizes_w[i] / self.sizes_b[i])
            weights = tf.reshape(weights, [w_div, self.sizes_b[i]])
            biases = w[end_weights:end_weights + self.sizes_b[i]]
            weights_biases = [weights, biases]
            layer.set_weights(weights_biases)
        self.lambda_1.assign([w[-2]])
        self.lambda_2.assign([w[-1]])

    # 获取当前参数值
    def get_params(self, numpy=False):
        l1 = self.lambda_1
        l2 = self.lambda_2
        if numpy:
            return l1.numpy()[0], l2.numpy()[0]
        return l1, l2

    # 打印模型摘要
    def summary(self):
        return self.u_model.summary()

    # 小批量采样
    def mini_batch(self, X_u, u, batch_size):
        idx_u = np.random.randint(0, tf.shape(X_u).numpy()[0], batch_size)
        X_u_batch = tf.gather(X_u, idx_u)
        u_batch = tf.gather(u, idx_u)
        return X_u_batch, u_batch

    # L-BFGS回调函数
    def lbfgs_callback(self, weights, X_u, u):
        """每次L-BFGS迭代后更新历史记录"""
        self.set_weights(weights)
        current_l1, current_l2 = self.get_params(numpy=True)

        # 记录当前参数值
        global callback_lbfgs_l1s, callback_lbfgs_l2s
        callback_lbfgs_l1s.append(current_l1)
        callback_lbfgs_l2s.append(current_l2)

        # 每10次迭代输出一次
        if len(callback_lbfgs_l1s) % 10 == 0:
            print(f"L-BFGS step {len(callback_lbfgs_l1s)}: l1 = {current_l1:.6f}, l2 = {current_l2:.6f}")

        return False  # 返回False继续优化

    # 训练函数
    def fit(self, X_u, u, tf_epochs, batch_size=512):
        global callback_lbfgs_iterations, callback_lbfgs_losses, callback_lbfgs_l1s, callback_lbfgs_l2s
        self.logger.log_train_start(self)

        # 转换为张量
        X_u = tf.convert_to_tensor(X_u, dtype=self.dtype)
        u = tf.convert_to_tensor(u, dtype=self.dtype)

        iter_per_epoch = int(np.floor(tf.shape(X_u).numpy()[0]/batch_size))

        def log_train_epoch(epoch, loss):
            l1, l2 = self.get_params(numpy=True)
            custom = f"l1 = {l1:4f} l2 = {l2:4f} adaptive_param = {self.adaptive_param:4f}"
            self.logger.log_train_epoch(epoch, loss, self.current_best_loss, custom)

        # ADAM优化
        self.logger.log_train_opt("Adam")
        for epoch in range(tf_epochs):
            for index in range(iter_per_epoch):
                X_u_batch, u_batch = self.mini_batch(X_u, u, batch_size)

                # 取消注释以启用自适应权重
                # self.__adaptive_param(X_u_batch, u_batch)

                # 优化步骤
                loss_value, grads = self.__grad(X_u_batch, u_batch)
                self.optimizer.apply_gradients(zip(grads, self.__wrap_training_variables()))

            # 在完整数据集上计算损失
            loss_u, loss_f = self.__loss(X_u, u, self.u_model(X_u))
            loss_value = self.adaptive_param*loss_u + 1.0*loss_f

            if loss_value < self.current_best_loss:
              self.current_best_loss = loss_value
              self.current_best_weights = self.get_weights()

            log_train_epoch(epoch, loss_value)

            # 记录历史
            self.loss_history.append(loss_value.numpy())
            l1, l2 = self.get_params(numpy=True)
            self.l1_history.append(l1)
            self.l2_history.append(l2)

        # 重置回调变量
        callback_lbfgs_iterations = []
        callback_lbfgs_losses = []
        callback_lbfgs_l1s = []
        callback_lbfgs_l2s = []

        # L-BFGS优化
        print("Starting L-BFGS training")

        # 存储ADAM优化后的参数
        adam_l1, adam_l2 = self.get_params(numpy=True)
        print(f"Parameters after ADAM: l1 = {adam_l1:.6f}, l2 = {adam_l2:.6f}")

        # 准备优化函数
        loss_and_flat_grad = self.get_loss_and_flat_grad(X_u, u)

        # 定义L-BFGS回调函数的闭包
        def callback_lbfgs_wrapper(xk):
            return self.lbfgs_callback(xk, X_u, u)

        # 运行L-BFGS优化
        lbfgs_weights, lbfgs_history, _ = lbfgs(
            loss_and_flat_grad,
            self.get_weights(),
            Struct(),
            maxIter=500,
            learningRate=0.8,
            do_verbose=False,  # 使用自定义日志
            callback=callback_lbfgs_wrapper  # 传递回调函数
        )

        # 应用最终权重
        self.set_weights(lbfgs_weights)

        # 检查L-BFGS是否改进了解决方案
        final_loss_u, final_loss_f = self.__loss(X_u, u, self.u_model(X_u))
        final_loss = self.adaptive_param*final_loss_u + 1.0*final_loss_f

        if final_loss < self.current_best_loss:
            self.current_best_loss = final_loss
            self.current_best_weights = lbfgs_weights

        # 将L-BFGS历史添加到总体历史
        for i in range(len(callback_lbfgs_losses)):
            self.loss_history.append(callback_lbfgs_losses[i])
            self.l1_history.append(callback_lbfgs_l1s[i])
            self.l2_history.append(callback_lbfgs_l2s[i])

        # 设置最佳权重
        self.set_weights(self.current_best_weights)
        final_l1, final_l2 = self.get_params(numpy=True)

        self.logger.log_train_end(
            tf_epochs,
            final_loss,
            self.current_best_loss,
            f"l1 = {final_l1:.6f}, l2 = {final_l2:.6f}"
        )

        return self.loss_history, self.l1_history, self.l2_history, self.adaptive_param_history

    # 预测函数
    def predict(self, X_star):
        u_star = self.u_model(X_star)
        f_star = self.__f_model(X_star)
        return u_star.numpy(), f_star.numpy()


# 定义误差计算函数
def error():
    """计算参数反演的相对误差"""
    l1, l2 = pinn.get_params(numpy=True)
    l1_star, l2_star = lambdas_star
    error_lambda_1 = np.abs(l1 - l1_star) / np.abs(l1_star)
    error_lambda_2 = np.abs(l2 - l2_star) / np.abs(l2_star)
    return (error_lambda_1 + error_lambda_2) / 2


# 主程序执行部分
if __name__ == "__main__":
    # 设置参数
    N_u = 5000  # 数据点数量
    layers = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]  # 神经网络层大小
    activation_func = tf.keras.activations.tanh  # 激活函数

    # ADAM优化器设置
    tf_epochs = 100  # ADAM优化轮数
    tf_optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
    batch_size = 5000  # 批量大小

    # 损失函数权重
    f_param = 1  # PDE损失权重
    u_param = 1  # 数据拟合损失权重

    # 真实参数值
    lambdas_star = (-0.8, 5.0)  # 源项位置、强度

    # 边界条件设置
    inc_bounds = True  # 是否包含边界条件
    ICBC =  1 # 边界条件点数量
    noise = 0.1  # 噪声水平

    # 加载数据
    path = "1D_ADE_Training_Data.mat"  # 数据文件路径
    x, t, X, T, X_star, u_star, X_u_train, u_train, ub, lb = prep_data_dense(path, N_u, noise, inc_bounds, ICBC)

    # 可视化训练数据
    TrainingDataPlotter(X_u_train, ub, lb)

    # 创建模型并训练
    logger = Logger(frequency=1)
    logger.set_error_fn(error)
    pinn = PhysicsInformedNN(layers, tf_optimizer, logger, ub, lb, f_param, u_param, activation_func)

    # 训练模型
    loss_history, l1_history, l2_history, adaptive_param_history = pinn.fit(X_u_train, u_train, tf_epochs, batch_size)

    # 绘制损失和参数历史
    LossParameterPlotter(loss_history, l1_history, l2_history)

    # 提取数据并可视化结果
    u_star_plot, u_plot, u_train_pred, trained_weights = ExtractData(pinn, X_star, X_u_train, u_star)
    DiscretePlotter(x, t, u_plot, u_star_plot, lb, ub)

    # 保存结果
    savemat('PINNresults1DInverse.mat', {
        'u_pred': u_plot,
        'u_true': u_star_plot,
        'loss_history': loss_history,
        'l1_history': l1_history,
        'l2_history': l2_history,
        'adaptive_param_history': adaptive_param_history,
        'X_u_train': X_u_train,
        'u_train': u_train,
        'u_train_pred': u_train_pred,
        'X': X,
        'T': T,
        'X_star': X_star,
        'x': x,
        't': t,
        'layers': layers,
        'noise': noise,
        'u_param': u_param,
        'f_param': f_param
    })

    # 输出最终参数
    final_l1, final_l2 = pinn.get_params(numpy=True)
    print(f"\nFinal Parameters:")
    print(f"Source Position (l1): {final_l1:.6f} (True: {lambdas_star[0]})")
    print(f"Source Strength (l2): {final_l2:.6f} (True: {lambdas_star[1]})")
    print(f"Relative Error: {error():.6f}")
# Out:
# WARNING:tensorflow:From <ipython-input-4-a4409f5c961a>:450: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# Amount of training data: 5004
# TensorFlow version: 2.18.0
# Eager execution: True
# GPU-accerelated: False
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Training started
# ================
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lambda (Lambda)                      │ (None, 2)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 20)                  │              60 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 20)                  │             420 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 20)                  │             420 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 20)                  │             420 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 20)                  │             420 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 20)                  │             420 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 20)                  │             420 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 20)                  │             420 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 1)                   │              21 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,021 (11.80 KB)
#  Trainable params: 3,021 (11.80 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# —— Starting Adam optimization ——
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# tf_epoch =      0  elapsed = 00:00:07  loss = 2.8396e-01  best loss = 2.8396e-01  error = 8.0072e-01  l1 = 0.001000 l2 = 1.999000 adaptive_param = 1.000000
# tf_epoch =      1  elapsed = 00:00:12  loss = 2.7715e-01  best loss = 2.7715e-01  error = 8.0134e-01  l1 = 0.001830 l2 = 1.997999 adaptive_param = 1.000000
# tf_epoch =      2  elapsed = 00:00:15  loss = 2.8020e-01  best loss = 2.7715e-01  error = 8.0192e-01  l1 = 0.002591 l2 = 1.996996 adaptive_param = 1.000000
# tf_epoch =      3  elapsed = 00:00:21  loss = 2.6930e-01  best loss = 2.6930e-01  error = 8.0255e-01  l1 = 0.003435 l2 = 1.995989 adaptive_param = 1.000000
# tf_epoch =      4  elapsed = 00:00:26  loss = 2.5433e-01  best loss = 2.5433e-01  error = 8.0283e-01  l1 = 0.003724 l2 = 1.994982 adaptive_param = 1.000000
# tf_epoch =      5  elapsed = 00:00:30  loss = 2.4435e-01  best loss = 2.4435e-01  error = 8.0278e-01  l1 = 0.003484 l2 = 1.993971 adaptive_param = 1.000000
# tf_epoch =      6  elapsed = 00:00:34  loss = 2.4328e-01  best loss = 2.4328e-01  error = 8.0272e-01  l1 = 0.003223 l2 = 1.992960 adaptive_param = 1.000000
# tf_epoch =      7  elapsed = 00:00:37  loss = 2.4727e-01  best loss = 2.4328e-01  error = 8.0257e-01  l1 = 0.002826 l2 = 1.991956 adaptive_param = 1.000000
# tf_epoch =      8  elapsed = 00:00:42  loss = 2.5053e-01  best loss = 2.4328e-01  error = 8.0244e-01  l1 = 0.002451 l2 = 1.990958 adaptive_param = 1.000000
# tf_epoch =      9  elapsed = 00:00:47  loss = 2.5042e-01  best loss = 2.4328e-01  error = 8.0231e-01  l1 = 0.002096 l2 = 1.989964 adaptive_param = 1.000000
# tf_epoch =     10  elapsed = 00:00:50  loss = 2.4738e-01  best loss = 2.4328e-01  error = 8.0216e-01  l1 = 0.001684 l2 = 1.988972 adaptive_param = 1.000000
# tf_epoch =     11  elapsed = 00:00:53  loss = 2.4334e-01  best loss = 2.4328e-01  error = 8.0198e-01  l1 = 0.001248 l2 = 1.987987 adaptive_param = 1.000000
# tf_epoch =     12  elapsed = 00:00:55  loss = 2.4021e-01  best loss = 2.4021e-01  error = 8.0186e-01  l1 = 0.000893 l2 = 1.987001 adaptive_param = 1.000000
# tf_epoch =     13  elapsed = 00:00:57  loss = 2.3853e-01  best loss = 2.3853e-01  error = 8.0169e-01  l1 = 0.000467 l2 = 1.986016 adaptive_param = 1.000000
# tf_epoch =     14  elapsed = 00:01:00  loss = 2.3791e-01  best loss = 2.3791e-01  error = 8.0142e-01  l1 = -0.000119 l2 = 1.985029 adaptive_param = 1.000000
# tf_epoch =     15  elapsed = 00:01:02  loss = 2.3770e-01  best loss = 2.3770e-01  error = 8.0118e-01  l1 = -0.000668 l2 = 1.984044 adaptive_param = 1.000000
# tf_epoch =     16  elapsed = 00:01:03  loss = 2.3719e-01  best loss = 2.3719e-01  error = 8.0098e-01  l1 = -0.001144 l2 = 1.983057 adaptive_param = 1.000000
# tf_epoch =     17  elapsed = 00:01:04  loss = 2.3607e-01  best loss = 2.3607e-01  error = 8.0082e-01  l1 = -0.001553 l2 = 1.982067 adaptive_param = 1.000000
# tf_epoch =     18  elapsed = 00:01:05  loss = 2.3440e-01  best loss = 2.3440e-01  error = 8.0064e-01  l1 = -0.002012 l2 = 1.981076 adaptive_param = 1.000000
# tf_epoch =     19  elapsed = 00:01:06  loss = 2.3250e-01  best loss = 2.3250e-01  error = 8.0047e-01  l1 = -0.002439 l2 = 1.980082 adaptive_param = 1.000000
# tf_epoch =     20  elapsed = 00:01:06  loss = 2.3065e-01  best loss = 2.3065e-01  error = 8.0031e-01  l1 = -0.002858 l2 = 1.979082 adaptive_param = 1.000000
# tf_epoch =     21  elapsed = 00:01:07  loss = 2.2928e-01  best loss = 2.2928e-01  error = 8.0024e-01  l1 = -0.003123 l2 = 1.978084 adaptive_param = 1.000000
# tf_epoch =     22  elapsed = 00:01:08  loss = 2.2842e-01  best loss = 2.2842e-01  error = 8.0015e-01  l1 = -0.003426 l2 = 1.977087 adaptive_param = 1.000000
# tf_epoch =     23  elapsed = 00:01:09  loss = 2.2798e-01  best loss = 2.2798e-01  error = 8.0004e-01  l1 = -0.003760 l2 = 1.976090 adaptive_param = 1.000000
# tf_epoch =     24  elapsed = 00:01:10  loss = 2.2773e-01  best loss = 2.2773e-01  error = 7.9995e-01  l1 = -0.004066 l2 = 1.975096 adaptive_param = 1.000000
# tf_epoch =     25  elapsed = 00:01:11  loss = 2.2725e-01  best loss = 2.2725e-01  error = 7.9989e-01  l1 = -0.004317 l2 = 1.974110 adaptive_param = 1.000000
# tf_epoch =     26  elapsed = 00:01:11  loss = 2.2639e-01  best loss = 2.2639e-01  error = 7.9983e-01  l1 = -0.004570 l2 = 1.973129 adaptive_param = 1.000000
# tf_epoch =     27  elapsed = 00:01:12  loss = 2.2515e-01  best loss = 2.2515e-01  error = 7.9971e-01  l1 = -0.004919 l2 = 1.972153 adaptive_param = 1.000000
# tf_epoch =     28  elapsed = 00:01:13  loss = 2.2374e-01  best loss = 2.2374e-01  error = 7.9956e-01  l1 = -0.005313 l2 = 1.971180 adaptive_param = 1.000000
# tf_epoch =     29  elapsed = 00:01:14  loss = 2.2238e-01  best loss = 2.2238e-01  error = 7.9944e-01  l1 = -0.005664 l2 = 1.970207 adaptive_param = 1.000000
# tf_epoch =     30  elapsed = 00:01:15  loss = 2.2118e-01  best loss = 2.2118e-01  error = 7.9934e-01  l1 = -0.005974 l2 = 1.969230 adaptive_param = 1.000000
# tf_epoch =     31  elapsed = 00:01:16  loss = 2.2003e-01  best loss = 2.2003e-01  error = 7.9928e-01  l1 = -0.006237 l2 = 1.968251 adaptive_param = 1.000000
# tf_epoch =     32  elapsed = 00:01:17  loss = 2.1885e-01  best loss = 2.1885e-01  error = 7.9932e-01  l1 = -0.006329 l2 = 1.967270 adaptive_param = 1.000000
# tf_epoch =     33  elapsed = 00:01:18  loss = 2.1753e-01  best loss = 2.1753e-01  error = 7.9942e-01  l1 = -0.006325 l2 = 1.966290 adaptive_param = 1.000000
# tf_epoch =     34  elapsed = 00:01:19  loss = 2.1600e-01  best loss = 2.1600e-01  error = 7.9956e-01  l1 = -0.006252 l2 = 1.965307 adaptive_param = 1.000000
# tf_epoch =     35  elapsed = 00:01:20  loss = 2.1442e-01  best loss = 2.1442e-01  error = 7.9965e-01  l1 = -0.006271 l2 = 1.964328 adaptive_param = 1.000000
# tf_epoch =     36  elapsed = 00:01:20  loss = 2.1286e-01  best loss = 2.1286e-01  error = 7.9975e-01  l1 = -0.006267 l2 = 1.963352 adaptive_param = 1.000000
# tf_epoch =     37  elapsed = 00:01:21  loss = 2.1134e-01  best loss = 2.1134e-01  error = 7.9991e-01  l1 = -0.006171 l2 = 1.962380 adaptive_param = 1.000000
# tf_epoch =     38  elapsed = 00:01:22  loss = 2.0981e-01  best loss = 2.0981e-01  error = 8.0000e-01  l1 = -0.006173 l2 = 1.961406 adaptive_param = 1.000000
# tf_epoch =     39  elapsed = 00:01:23  loss = 2.0812e-01  best loss = 2.0812e-01  error = 8.0002e-01  l1 = -0.006297 l2 = 1.960436 adaptive_param = 1.000000
# tf_epoch =     40  elapsed = 00:01:24  loss = 2.0615e-01  best loss = 2.0615e-01  error = 8.0015e-01  l1 = -0.006243 l2 = 1.959471 adaptive_param = 1.000000
# tf_epoch =     41  elapsed = 00:01:24  loss = 2.0388e-01  best loss = 2.0388e-01  error = 8.0028e-01  l1 = -0.006192 l2 = 1.958506 adaptive_param = 1.000000
# tf_epoch =     42  elapsed = 00:01:25  loss = 2.0132e-01  best loss = 2.0132e-01  error = 8.0043e-01  l1 = -0.006103 l2 = 1.957550 adaptive_param = 1.000000
# tf_epoch =     43  elapsed = 00:01:26  loss = 1.9865e-01  best loss = 1.9865e-01  error = 8.0061e-01  l1 = -0.005971 l2 = 1.956595 adaptive_param = 1.000000
# tf_epoch =     44  elapsed = 00:01:27  loss = 1.9595e-01  best loss = 1.9595e-01  error = 8.0085e-01  l1 = -0.005734 l2 = 1.955646 adaptive_param = 1.000000
# tf_epoch =     45  elapsed = 00:01:28  loss = 1.9307e-01  best loss = 1.9307e-01  error = 8.0102e-01  l1 = -0.005613 l2 = 1.954697 adaptive_param = 1.000000
# tf_epoch =     46  elapsed = 00:01:28  loss = 1.8977e-01  best loss = 1.8977e-01  error = 8.0122e-01  l1 = -0.005442 l2 = 1.953747 adaptive_param = 1.000000
# tf_epoch =     47  elapsed = 00:01:29  loss = 1.8628e-01  best loss = 1.8628e-01  error = 8.0130e-01  l1 = -0.005478 l2 = 1.952807 adaptive_param = 1.000000
# tf_epoch =     48  elapsed = 00:01:30  loss = 1.8238e-01  best loss = 1.8238e-01  error = 8.0141e-01  l1 = -0.005449 l2 = 1.951867 adaptive_param = 1.000000
# tf_epoch =     49  elapsed = 00:01:31  loss = 1.7833e-01  best loss = 1.7833e-01  error = 8.0153e-01  l1 = -0.005405 l2 = 1.950936 adaptive_param = 1.000000
# tf_epoch =     50  elapsed = 00:01:32  loss = 1.7406e-01  best loss = 1.7406e-01  error = 8.0161e-01  l1 = -0.005421 l2 = 1.950009 adaptive_param = 1.000000
# tf_epoch =     51  elapsed = 00:01:33  loss = 1.6942e-01  best loss = 1.6942e-01  error = 8.0180e-01  l1 = -0.005266 l2 = 1.949089 adaptive_param = 1.000000
# tf_epoch =     52  elapsed = 00:01:34  loss = 1.6416e-01  best loss = 1.6416e-01  error = 8.0201e-01  l1 = -0.005075 l2 = 1.948182 adaptive_param = 1.000000
# tf_epoch =     53  elapsed = 00:01:35  loss = 1.5873e-01  best loss = 1.5873e-01  error = 8.0225e-01  l1 = -0.004837 l2 = 1.947287 adaptive_param = 1.000000
# tf_epoch =     54  elapsed = 00:01:36  loss = 1.5338e-01  best loss = 1.5338e-01  error = 8.0256e-01  l1 = -0.004475 l2 = 1.946405 adaptive_param = 1.000000
# tf_epoch =     55  elapsed = 00:01:37  loss = 1.4772e-01  best loss = 1.4772e-01  error = 8.0285e-01  l1 = -0.004148 l2 = 1.945528 adaptive_param = 1.000000
# tf_epoch =     56  elapsed = 00:01:38  loss = 1.4183e-01  best loss = 1.4183e-01  error = 8.0315e-01  l1 = -0.003806 l2 = 1.944666 adaptive_param = 1.000000
# tf_epoch =     57  elapsed = 00:01:38  loss = 1.3599e-01  best loss = 1.3599e-01  error = 8.0345e-01  l1 = -0.003462 l2 = 1.943825 adaptive_param = 1.000000
# tf_epoch =     58  elapsed = 00:01:39  loss = 1.3006e-01  best loss = 1.3006e-01  error = 8.0377e-01  l1 = -0.003087 l2 = 1.943002 adaptive_param = 1.000000
# tf_epoch =     59  elapsed = 00:01:40  loss = 1.2384e-01  best loss = 1.2384e-01  error = 8.0410e-01  l1 = -0.002682 l2 = 1.942200 adaptive_param = 1.000000
# tf_epoch =     60  elapsed = 00:01:41  loss = 1.1762e-01  best loss = 1.1762e-01  error = 8.0443e-01  l1 = -0.002291 l2 = 1.941427 adaptive_param = 1.000000
# tf_epoch =     61  elapsed = 00:01:42  loss = 1.1138e-01  best loss = 1.1138e-01  error = 8.0473e-01  l1 = -0.001919 l2 = 1.940682 adaptive_param = 1.000000
# tf_epoch =     62  elapsed = 00:01:42  loss = 1.0434e-01  best loss = 1.0434e-01  error = 8.0502e-01  l1 = -0.001569 l2 = 1.939965 adaptive_param = 1.000000
# tf_epoch =     63  elapsed = 00:01:43  loss = 9.7345e-02  best loss = 9.7345e-02  error = 8.0533e-01  l1 = -0.001180 l2 = 1.939278 adaptive_param = 1.000000
# tf_epoch =     64  elapsed = 00:01:44  loss = 9.0341e-02  best loss = 9.0341e-02  error = 8.0563e-01  l1 = -0.000819 l2 = 1.938630 adaptive_param = 1.000000
# tf_epoch =     65  elapsed = 00:01:45  loss = 8.3252e-02  best loss = 8.3252e-02  error = 8.0596e-01  l1 = -0.000386 l2 = 1.938022 adaptive_param = 1.000000
# tf_epoch =     66  elapsed = 00:01:45  loss = 7.6410e-02  best loss = 7.6410e-02  error = 8.0631e-01  l1 = 0.000088 l2 = 1.937451 adaptive_param = 1.000000
# tf_epoch =     67  elapsed = 00:01:46  loss = 6.9853e-02  best loss = 6.9853e-02  error = 8.0665e-01  l1 = 0.000542 l2 = 1.936918 adaptive_param = 1.000000
# tf_epoch =     68  elapsed = 00:01:47  loss = 6.3604e-02  best loss = 6.3604e-02  error = 8.0695e-01  l1 = 0.000951 l2 = 1.936424 adaptive_param = 1.000000
# tf_epoch =     69  elapsed = 00:01:48  loss = 5.7850e-02  best loss = 5.7850e-02  error = 8.0722e-01  l1 = 0.001301 l2 = 1.935970 adaptive_param = 1.000000
# tf_epoch =     70  elapsed = 00:01:49  loss = 5.2971e-02  best loss = 5.2971e-02  error = 8.0745e-01  l1 = 0.001610 l2 = 1.935555 adaptive_param = 1.000000
# tf_epoch =     71  elapsed = 00:01:50  loss = 4.9341e-02  best loss = 4.9341e-02  error = 8.0766e-01  l1 = 0.001879 l2 = 1.935178 adaptive_param = 1.000000
# tf_epoch =     72  elapsed = 00:01:51  loss = 4.7116e-02  best loss = 4.7116e-02  error = 8.0787e-01  l1 = 0.002167 l2 = 1.934835 adaptive_param = 1.000000
# tf_epoch =     73  elapsed = 00:01:52  loss = 4.6207e-02  best loss = 4.6207e-02  error = 8.0809e-01  l1 = 0.002460 l2 = 1.934525 adaptive_param = 1.000000
# tf_epoch =     74  elapsed = 00:01:53  loss = 4.6405e-02  best loss = 4.6207e-02  error = 8.0833e-01  l1 = 0.002806 l2 = 1.934239 adaptive_param = 1.000000
# tf_epoch =     75  elapsed = 00:01:53  loss = 4.7232e-02  best loss = 4.6207e-02  error = 8.0852e-01  l1 = 0.003070 l2 = 1.933973 adaptive_param = 1.000000
# tf_epoch =     76  elapsed = 00:01:54  loss = 4.8191e-02  best loss = 4.6207e-02  error = 8.0866e-01  l1 = 0.003244 l2 = 1.933722 adaptive_param = 1.000000
# tf_epoch =     77  elapsed = 00:01:55  loss = 4.8603e-02  best loss = 4.6207e-02  error = 8.0872e-01  l1 = 0.003303 l2 = 1.933487 adaptive_param = 1.000000
# tf_epoch =     78  elapsed = 00:01:55  loss = 4.8595e-02  best loss = 4.6207e-02  error = 8.0872e-01  l1 = 0.003280 l2 = 1.933264 adaptive_param = 1.000000
# tf_epoch =     79  elapsed = 00:01:56  loss = 4.8441e-02  best loss = 4.6207e-02  error = 8.0871e-01  l1 = 0.003229 l2 = 1.933049 adaptive_param = 1.000000
# tf_epoch =     80  elapsed = 00:01:56  loss = 4.7186e-02  best loss = 4.6207e-02  error = 8.0874e-01  l1 = 0.003237 l2 = 1.932840 adaptive_param = 1.000000
# tf_epoch =     81  elapsed = 00:01:57  loss = 4.5968e-02  best loss = 4.5968e-02  error = 8.0879e-01  l1 = 0.003285 l2 = 1.932637 adaptive_param = 1.000000
# tf_epoch =     82  elapsed = 00:01:57  loss = 4.4905e-02  best loss = 4.4905e-02  error = 8.0881e-01  l1 = 0.003288 l2 = 1.932444 adaptive_param = 1.000000
# tf_epoch =     83  elapsed = 00:01:58  loss = 4.3587e-02  best loss = 4.3587e-02  error = 8.0876e-01  l1 = 0.003181 l2 = 1.932262 adaptive_param = 1.000000
# tf_epoch =     84  elapsed = 00:01:59  loss = 4.2188e-02  best loss = 4.2188e-02  error = 8.0864e-01  l1 = 0.002958 l2 = 1.932088 adaptive_param = 1.000000
# tf_epoch =     85  elapsed = 00:01:59  loss = 4.0766e-02  best loss = 4.0766e-02  error = 8.0851e-01  l1 = 0.002731 l2 = 1.931921 adaptive_param = 1.000000
# tf_epoch =     86  elapsed = 00:02:00  loss = 3.9394e-02  best loss = 3.9394e-02  error = 8.0842e-01  l1 = 0.002546 l2 = 1.931760 adaptive_param = 1.000000
# tf_epoch =     87  elapsed = 00:02:00  loss = 3.8224e-02  best loss = 3.8224e-02  error = 8.0835e-01  l1 = 0.002421 l2 = 1.931604 adaptive_param = 1.000000
# tf_epoch =     88  elapsed = 00:02:01  loss = 3.7318e-02  best loss = 3.7318e-02  error = 8.0832e-01  l1 = 0.002342 l2 = 1.931454 adaptive_param = 1.000000
# tf_epoch =     89  elapsed = 00:02:01  loss = 3.6783e-02  best loss = 3.6783e-02  error = 8.0828e-01  l1 = 0.002261 l2 = 1.931307 adaptive_param = 1.000000
# tf_epoch =     90  elapsed = 00:02:02  loss = 3.6527e-02  best loss = 3.6527e-02  error = 8.0823e-01  l1 = 0.002150 l2 = 1.931159 adaptive_param = 1.000000
# tf_epoch =     91  elapsed = 00:02:03  loss = 3.6389e-02  best loss = 3.6389e-02  error = 8.0814e-01  l1 = 0.001990 l2 = 1.931013 adaptive_param = 1.000000
# tf_epoch =     92  elapsed = 00:02:04  loss = 3.6216e-02  best loss = 3.6216e-02  error = 8.0805e-01  l1 = 0.001822 l2 = 1.930872 adaptive_param = 1.000000
# tf_epoch =     93  elapsed = 00:02:05  loss = 3.6133e-02  best loss = 3.6133e-02  error = 8.0794e-01  l1 = 0.001623 l2 = 1.930736 adaptive_param = 1.000000
# tf_epoch =     94  elapsed = 00:02:05  loss = 3.5991e-02  best loss = 3.5991e-02  error = 8.0785e-01  l1 = 0.001456 l2 = 1.930603 adaptive_param = 1.000000
# tf_epoch =     95  elapsed = 00:02:06  loss = 3.5860e-02  best loss = 3.5860e-02  error = 8.0780e-01  l1 = 0.001350 l2 = 1.930474 adaptive_param = 1.000000
# tf_epoch =     96  elapsed = 00:02:07  loss = 3.5748e-02  best loss = 3.5748e-02  error = 8.0774e-01  l1 = 0.001243 l2 = 1.930353 adaptive_param = 1.000000
# tf_epoch =     97  elapsed = 00:02:07  loss = 3.5485e-02  best loss = 3.5485e-02  error = 8.0769e-01  l1 = 0.001139 l2 = 1.930239 adaptive_param = 1.000000
# tf_epoch =     98  elapsed = 00:02:08  loss = 3.5229e-02  best loss = 3.5229e-02  error = 8.0763e-01  l1 = 0.001035 l2 = 1.930131 adaptive_param = 1.000000
# tf_epoch =     99  elapsed = 00:02:08  loss = 3.4937e-02  best loss = 3.4937e-02  error = 8.0756e-01  l1 = 0.000902 l2 = 1.930029 adaptive_param = 1.000000
# Starting L-BFGS training
# Parameters after ADAM: l1 = 0.000902, l2 = 1.930029
# L-BFGS step 10: l1 = -0.005276, l2 = 1.920681
# L-BFGS step 20: l1 = -0.038683, l2 = 1.879649
# L-BFGS step 30: l1 = -0.087995, l2 = 1.810347
# L-BFGS step 40: l1 = -0.255335, l2 = 1.572284
# L-BFGS step 50: l1 = -0.697332, l2 = 1.025526
# L-BFGS step 60: l1 = -0.699368, l2 = 1.093570
# L-BFGS step 70: l1 = -0.720457, l2 = 1.432058
# L-BFGS step 80: l1 = -0.744263, l2 = 1.799987
# L-BFGS step 90: l1 = -0.776181, l2 = 2.409360
# L-BFGS step 100: l1 = -0.782190, l2 = 2.897281
# L-BFGS step 110: l1 = -0.787269, l2 = 3.308056
# L-BFGS step 120: l1 = -0.788749, l2 = 3.548158
# L-BFGS step 130: l1 = -0.786581, l2 = 3.921632
# L-BFGS step 140: l1 = -0.784140, l2 = 3.955113
# L-BFGS step 150: l1 = -0.784332, l2 = 4.215296
# L-BFGS step 160: l1 = -0.797188, l2 = 4.579121
# L-BFGS step 170: l1 = -0.806467, l2 = 4.906955
# L-BFGS step 180: l1 = -0.803657, l2 = 4.687892
# L-BFGS step 190: l1 = -0.802273, l2 = 4.649776
# L-BFGS step 200: l1 = -0.807277, l2 = 4.839920
# L-BFGS step 210: l1 = -0.806681, l2 = 4.824414
# L-BFGS step 220: l1 = -0.807115, l2 = 4.818738
# L-BFGS step 230: l1 = -0.806261, l2 = 4.912147
# L-BFGS step 240: l1 = -0.809170, l2 = 4.924478
# L-BFGS step 250: l1 = -0.808991, l2 = 4.886822
# L-BFGS step 260: l1 = -0.809698, l2 = 4.923040
# L-BFGS step 270: l1 = -0.805600, l2 = 4.822807
# L-BFGS step 280: l1 = -0.805261, l2 = 4.831750
# L-BFGS step 290: l1 = -0.805086, l2 = 4.815226
# L-BFGS step 300: l1 = -0.804806, l2 = 4.866758
# L-BFGS step 310: l1 = -0.803210, l2 = 4.772726
# L-BFGS step 320: l1 = -0.801243, l2 = 4.749324
# L-BFGS step 330: l1 = -0.799944, l2 = 4.744104
# L-BFGS step 340: l1 = -0.805620, l2 = 4.931409
# L-BFGS step 350: l1 = -0.805630, l2 = 4.926628
# L-BFGS step 360: l1 = -0.804854, l2 = 4.883899
# L-BFGS step 370: l1 = -0.803937, l2 = 4.906654
# L-BFGS step 380: l1 = -0.804527, l2 = 4.883209
# L-BFGS step 390: l1 = -0.805760, l2 = 4.955937
# L-BFGS step 400: l1 = -0.806078, l2 = 4.995640
# L-BFGS step 410: l1 = -0.807666, l2 = 5.028341
# L-BFGS step 420: l1 = -0.808399, l2 = 5.086227
# L-BFGS step 430: l1 = -0.807886, l2 = 5.047035
# L-BFGS step 440: l1 = -0.805863, l2 = 4.992373
# L-BFGS step 450: l1 = -0.806170, l2 = 5.023357
# L-BFGS step 460: l1 = -0.805563, l2 = 5.003559
# L-BFGS step 470: l1 = -0.805893, l2 = 5.029438
# L-BFGS step 480: l1 = -0.805777, l2 = 5.007967
# L-BFGS step 490: l1 = -0.804199, l2 = 5.006218
# L-BFGS step 500: l1 = -0.805014, l2 = 5.013633
# ==================
# Training finished (epoch 100): duration = 00:05:57  loss = 9.7231e-04  best loss = 9.7231e-04  error = 4.1742e-03  l1 = -0.805291, l2 = 5.008672
# Applying the weights at the best epoch to the model...
# Final Parameters:
# Source Position (l1): -0.805291 (True: -0.8)
# Source Strength (l2): 5.008672 (True: 5.0)
# Relative Error: 0.004174

# %%
import sys
import os
import time
from datetime import datetime
import tensorflow as tf
import numpy as np
import scipy.io
import tensorflow_probability as tfp
from pyDOE import lhs

import matplotlib
from scipy.io import savemat
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from scipy.interpolate import griddata
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# LBFGS回调全局变量
callback_lbfgs_iterations = []
callback_lbfgs_losses = []
callback_lbfgs_l1s = []
callback_lbfgs_l2s = []

def dot(a, b):
  """Dot product function since TensorFlow doesn't have one."""
  return tf.reduce_sum(a*b)

def verbose_func(s):
  print(s)

final_loss = None
times = []
def lbfgs(opfunc, x, state, maxIter=100, learningRate=1, do_verbose=True, callback=None):
  """port of lbfgs.lua, using TensorFlow eager mode.
  """

  global final_loss, times, callback_lbfgs_iterations, callback_lbfgs_losses, callback_lbfgs_l1s, callback_lbfgs_l2s

  # 清空全局回调变量
  callback_lbfgs_iterations = []
  callback_lbfgs_losses = []
  callback_lbfgs_l1s = []
  callback_lbfgs_l2s = []

  maxEval = maxIter*1.25
  tolFun = 1e-5
  tolX = 1e-9
  nCorrection = 50
  isverbose = False

  # verbose function
  if isverbose:
    verbose = verbose_func
  else:
    verbose = lambda x: None

  f, g = opfunc(x)

  # 初始回调
  if callback is not None:
    callback_lbfgs_iterations.append(0)
    callback_lbfgs_losses.append(f.numpy())
    callback(x)

  f_hist = [f]
  currentFuncEval = 1
  state.funcEval = state.funcEval + 1
  p = g.shape[0]

  # check optimality of initial point
  tmp1 = tf.abs(g)
  if tf.reduce_sum(tmp1) <= tolFun:
    verbose("optimality condition below tolFun")
    return x, f_hist

  # optimize for a max of maxIter iterations
  nIter = 0
  times = []
  while nIter < maxIter:
    start_time = time.time()

    # keep track of nb of iterations
    nIter = nIter + 1
    state.nIter = state.nIter + 1

    ############################################################
    ## compute gradient descent direction
    ############################################################
    if state.nIter == 1:
      d = -g
      old_dirs = []
      old_stps = []
      Hdiag = 1
    else:
      # do lbfgs update (update memory)
      y = g - g_old
      s = d*t
      ys = dot(y, s)

      if ys > 1e-10:
        # updating memory
        if len(old_dirs) == nCorrection:
          # shift history by one (limited-memory)
          del old_dirs[0]
          del old_stps[0]

        # store new direction/step
        old_dirs.append(s)
        old_stps.append(y)

        # update scale of initial Hessian approximation
        Hdiag = ys/dot(y, y)

      # compute the approximate (L-BFGS) inverse Hessian
      # multiplied by the gradient
      k = len(old_dirs)

      # need to be accessed element-by-element, so don't re-type tensor:
      ro = [0]*nCorrection
      for i in range(k):
        ro[i] = 1/dot(old_stps[i], old_dirs[i])


      # iteration in L-BFGS loop collapsed to use just one buffer
      # need to be accessed element-by-element, so don't re-type tensor:
      al = [0]*nCorrection

      q = -g
      for i in range(k-1, -1, -1):
        al[i] = dot(old_dirs[i], q) * ro[i]
        q = q - al[i]*old_stps[i]

      # multiply by initial Hessian
      r = q*Hdiag
      for i in range(k):
        be_i = dot(old_stps[i], r) * ro[i]
        r += (al[i]-be_i)*old_dirs[i]

      d = r
      # final direction is in r/d (same object)

    g_old = g
    f_old = f

    ############################################################
    ## compute step length
    ############################################################
    # directional derivative
    gtd = dot(g, d)

    # check that progress can be made along that direction
    if gtd > -tolX:
      verbose("Can not make progress along direction.")
      break

    # reset initial guess for step size
    if state.nIter == 1:
      tmp1 = tf.abs(g)
      t = min(1, 1/tf.reduce_sum(tmp1))
    else:
      t = learningRate

    x += t*d

    if nIter != maxIter:
      # re-evaluate function only if not in last iteration
      # the reason we do this: in a stochastic setting,
      # no use to re-evaluate that function here
      f, g = opfunc(x)

    lsFuncEval = 1
    f_hist.append(f)

    # 在每次迭代后调用回调函数
    if callback is not None:
      callback_lbfgs_iterations.append(nIter)
      callback_lbfgs_losses.append(f.numpy())
      callback(x)

    # update func eval
    currentFuncEval = currentFuncEval + lsFuncEval
    state.funcEval = state.funcEval + lsFuncEval

    ############################################################
    ## check conditions
    ############################################################
    if nIter == maxIter:
      break

    if currentFuncEval >= maxEval:
      # max nb of function evals
      print('max nb of function evals')
      break

    tmp1 = tf.abs(g)
    if tf.reduce_sum(tmp1) <=tolFun:
      # check optimality
      print('optimality condition below tolFun')
      break

    tmp1 = tf.abs(d*t)
    if tf.reduce_sum(tmp1) <= tolX:
      # step size below tolX
      print('step size below tolX')
      break

    if tf.abs(f,f_old) < tolX:
      # function value changing less than tolX
      print('function value changing less than tolX'+str(tf.abs(f-f_old)))
      break

    if do_verbose:
      if nIter % 10 == 0:
        print("Step %3d loss %6.5f "%(nIter, f.numpy()))


    if nIter == maxIter - 1:
      final_loss = f.numpy()


  # save state
  state.old_dirs = old_dirs
  state.old_stps = old_stps
  state.Hdiag = Hdiag
  state.g_old = g_old
  state.f_old = f_old
  state.t = t
  state.d = d

  return x, f_hist, currentFuncEval

# dummy/Struct gives Lua-like struct object with 0 defaults
class dummy(object):
  pass

class Struct(dummy):
  def __getattribute__(self, key):
    if key == '__dict__':
      return super(dummy, self).__getattribute__('__dict__')
    return self.__dict__.get(key, 0)


def prep_data_dense(path, N_u, noise, inc_bounds, ICBC):
    """准备PINN反演的数据"""
    data = scipy.io.loadmat(path)

    # Flatten makes [[]] into [], [:,None] makes it a column vector
    t = data['t'].flatten()[:,None] # T x 1
    x = data['x'].flatten()[:,None] # N x 1

    # Keeping the 2D data for the solution data
    Exact_u = np.real(data['u']) # T x N  (注意这里不进行转置)

    # Meshing x and t in 2D (256,100)
    X, T = np.meshgrid(x,t)

    # Preparing the inputs x and t (meshed as X, T) for predictions in one single array
    X_star = np.hstack((X.flatten()[:,None], T.flatten()[:,None]))

    # Preparing the testing u_star
    u_star = Exact_u.flatten()[:,None]

    # 随机选择内部点
    idx = np.random.choice(X_star.shape[0], N_u, replace=False)
    X_u_train = X_star[idx,:]
    u_train = u_star[idx,:]

    # 添加噪声
    u_train = u_train + noise*np.std(u_train)*np.random.randn(u_train.shape[0], u_train.shape[1])
    u_star = u_star + noise*np.std(u_star)*np.random.randn(u_star.shape[0], u_star.shape[1])

    # 如果需要包含边界条件
    if inc_bounds == True:
        # 获取初始条件(t=0)
        xx1 = np.hstack((X[0:1,:].flatten()[:,None], T[0:1,:].flatten()[:,None]))
        uu1 = Exact_u[0:1,:].flatten()[:,None]
        # 获取左边界条件(x=-1)
        xx2 = np.hstack((X[:,0:1].flatten()[:,None], T[:,0:1].flatten()[:,None]))
        uu2 = Exact_u[:,0:1].flatten()[:,None]
        # 获取右边界条件(x=1)
        xx3 = np.hstack((X[:,-1:].flatten()[:,None], T[:,-1:].flatten()[:,None]))
        uu3 = Exact_u[:,-1:].flatten()[:,None]

        # 堆叠边界条件
        X_u_bounds = np.vstack([xx1, xx2, xx3])
        u_bounds = np.vstack([uu1, uu2, uu3])

        # 从边界条件中随机选择ICBC个点
        size = X_u_bounds.shape[0]
        samples = int(ICBC)
        rnd_bounds = np.random.choice(size, samples, replace=False)
        X_u_bounds = X_u_bounds[rnd_bounds,:]
        u_bounds = u_bounds[rnd_bounds,:]

        # 将边界条件点添加到训练数据
        X_u_train = np.vstack([X_u_train, X_u_bounds])
        u_train = np.vstack([u_train, u_bounds])

    # 计算边界
    lb = X_star.min(axis=0)
    ub = X_star.max(axis=0)

    return x, t, X, T, X_star, u_star, X_u_train, u_train, ub, lb


def TrainingDataPlotter(X_u_train, ub, lb):
    """可视化训练数据点"""
    fig = plt.figure()
    ax = fig.add_subplot()

    ax.scatter(X_u_train[:,1], X_u_train[:,0], s=4.0, marker='o', alpha=1.0)

    ax.set_xlabel('t')
    ax.set_ylabel('x')
    ax.set_xlim(lb[1]-0.1, ub[1]+0.1)
    ax.set_ylim(lb[0]-0.1, ub[0]+0.1)

    plt.show()

    print('Amount of training data: ' + str(X_u_train.shape[0]))


def LossParameterPlotter(loss_history, l1_history, l2_history):
    """绘制损失和参数历史"""
    # 确保所有历史记录长度一致
    min_len = min(len(loss_history), len(l1_history), len(l2_history))
    loss_history = loss_history[:min_len]
    l1_history = l1_history[:min_len]
    l2_history = l2_history[:min_len]

    fig, axes = plt.subplots(2, sharex=True, figsize=(12, 12))
    fig.suptitle('Training Metrics')

    axes[0].set_ylabel("Loss", fontsize=14)
    axes[0].set_xlabel("Epoch", fontsize=14)
    axes[0].semilogy(loss_history)

    axes[1].set_ylabel("l1,l2", fontsize=14)
    axes[1].set_xlabel("Epoch", fontsize=14)
    axes[1].plot(l1_history, label='l1 (position)')
    axes[1].plot(l2_history, label='l2 (strength)')

    # 添加真实值参考线
    if 'lambdas_star' in globals():
        axes[1].hlines(lambdas_star[0], 0, len(l1_history), linestyles='dashed', label='True l1')
        axes[1].hlines(lambdas_star[1], 0, len(l2_history), linestyles='dashed', label='True l2')

    axes[1].legend()
    plt.show()


def DiscretePlotter(x, t, u_plot, u_star_plot, lb, ub):
    """绘制不同时间点的解决方案"""
    def figsize(scale, nplots=1):
        fig_width_pt = 390.0
        inches_per_pt = 1.0/72.27
        golden_mean = (np.sqrt(5.0)-1.0)/2.0
        fig_width = fig_width_pt*inches_per_pt*scale
        fig_height = nplots*fig_width*golden_mean
        fig_size = [fig_width, fig_height]
        return fig_size

    def newfig(width, nplots=1):
        fig = plt.figure(figsize=figsize(width, nplots))
        ax = fig.add_subplot(111)
        return fig, ax

    N_t = t.shape[0]
    Lt = ub[1] - lb[1]
    t0 = 0; t1 = Lt/5; t2 = 2*Lt/5; t3 = 3*Lt/5; t4 = 4*Lt/5; t5 = 5*Lt/5;
    N0 = int(np.ceil((t0*N_t)/Lt))
    N1 = int(np.ceil((t1*N_t)/Lt))
    N2 = int(np.ceil((t2*N_t)/Lt))
    N3 = int(np.ceil((t3*N_t)/Lt))
    N4 = int(np.ceil((t4*N_t)/Lt))
    N5 = int(np.floor((t5*N_t-1)/Lt))

    fig, ax = newfig(3.0, 3.0)
    gs1 = gridspec.GridSpec(2, 3)
    gs1.update(top=1-1.0/3.0-0.1, bottom=1.0-2.0/3.0, left=0.1, right=0.9, wspace=0.5)
    t0 = 0; t1 = Lt/5; t2 = 2*Lt/5; t3 = 3*Lt/5; t4 = 4*Lt/5; t5 = 5*Lt/5;
    N0 = int(np.ceil((t0*N_t)/Lt))
    N1 = int(np.ceil((t1*N_t)/Lt))
    N2 = int(np.ceil((t2*N_t)/Lt))
    N3 = int(np.ceil((t3*N_t)/Lt))
    N4 = int(np.ceil((t4*N_t)/Lt))
    N5 = int(np.floor((t5*N_t-1)/Lt))

    fig, ax = newfig(3.0, 3.0)
    gs1 = gridspec.GridSpec(2, 3)
    gs1.update(top=1-1.0/3.0-0.1, bottom=1.0-2.0/3.0, left=0.1, right=0.9, wspace=0.5)

    ax = plt.subplot(gs1[0, 0])
    ax.plot(x, u_star_plot[:,N0], 'b-', linewidth=2, label='Exact')
    ax.plot(x, u_plot[:,N0], 'r--', linewidth=2, label='Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')
    ax.set_title('$t = 0.0$', fontsize=10)
    ax.axis('square')
    ax.set_xlim([-1.1, 1.1])
    ax.set_ylim([-1.1, 1.1])

    ax = plt.subplot(gs1[0, 1])
    ax.plot(x, u_star_plot[:,N1], 'b-', linewidth=2, label='Exact')
    ax.plot(x, u_plot[:,N1], 'r--', linewidth=2, label='Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')
    ax.set_title('$t = 0.2$', fontsize=10)
    ax.axis('square')
    ax.set_xlim([-1.1, 1.1])
    ax.set_ylim([-1.1, 1.1])

    ax = plt.subplot(gs1[0, 2])
    ax.plot(x, u_star_plot[:,N2], 'b-', linewidth=2, label='Exact')
    ax.plot(x, u_plot[:,N2], 'r--', linewidth=2, label='Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')
    ax.set_title('$t = 0.4$', fontsize=10)
    ax.axis('square')
    ax.set_xlim([-1.1, 1.1])
    ax.set_ylim([-1.1, 1.1])

    ax = plt.subplot(gs1[1, 0])
    ax.plot(x, u_star_plot[:,N3], 'b-', linewidth=2, label='Exact')
    ax.plot(x, u_plot[:,N3], 'r--', linewidth=2, label='Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')
    ax.set_title('$t = 0.6$', fontsize=10)
    ax.axis('square')
    ax.set_xlim([-1.1, 1.1])
    ax.set_ylim([-1.1, 1.1])

    ax = plt.subplot(gs1[1, 1])
    ax.plot(x, u_star_plot[:,N4], 'b-', linewidth=2, label='Exact')
    ax.plot(x, u_plot[:,N4], 'r--', linewidth=2, label='Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')
    ax.set_title('$t = 0.8$', fontsize=10)
    ax.axis('square')
    ax.set_xlim([-1.1, 1.1])
    ax.set_ylim([-1.1, 1.1])

    ax = plt.subplot(gs1[1, 2])
    ax.plot(x, u_star_plot[:,N5], 'b-', linewidth=2, label='Exact')
    ax.plot(x, u_plot[:,N5], 'r--', linewidth=2, label='Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')
    ax.set_title('$t = 1.0$', fontsize=10)
    ax.axis('square')
    ax.set_xlim([-1.1, 1.1])
    ax.set_ylim([-1.1, 1.1])
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.35), ncol=5, frameon=False)
    plt.show()



def ExtractData(pinn, X_star, X_u_train, u_star):
    """从训练好的PINN提取数据"""
    # 对密集网格进行预测
    X_star_batches = np.array_split(X_star, 100)
    u_pred, _ = pinn.predict(X_star_batches[0])
    for i in range(len(X_star_batches)-1):
        u_pred_batch, _ = pinn.predict(X_star_batches[i+1])
        u_pred = np.vstack((u_pred, u_pred_batch))

    # 对训练点进行预测
    X_u_train_batches = np.array_split(X_u_train, 100)
    u_train_pred, _ = pinn.predict(X_u_train_batches[0])
    for i in range(len(X_u_train_batches)-1):
        u_train_batch, _ = pinn.predict(X_u_train_batches[i+1])
        u_train_pred = np.vstack((u_train_pred, u_train_batch))

    u_train_pred = u_train_pred.flatten()[:,None]

    N_x = x.shape[0]
    N_t = t.shape[0]

    # 重塑为网格形式
    u_plot = u_pred.reshape(N_t, N_x).T
    u_star_plot = u_star.reshape(N_t, N_x).T

    # 获取训练权重
    trained_weights = pinn.get_weights()

    return u_star_plot, u_plot, u_train_pred, trained_weights


class Logger(object):
    """日志记录器"""
    def __init__(self, frequency=10):
        print("TensorFlow version: {}".format(tf.__version__))
        print("Eager execution: {}".format(tf.executing_eagerly()))
        print("GPU-accerelated: {}".format(tf.test.is_gpu_available()))

        self.start_time = time.time()
        self.frequency = frequency

    def __get_elapsed(self):
        return datetime.fromtimestamp(time.time() - self.start_time).strftime("%H:%M:%S")

    def __get_error_u(self):
        return self.error_fn()

    def set_error_fn(self, error_fn):
        self.error_fn = error_fn

    def log_train_start(self, model):
        print("\nTraining started")
        print("================")
        self.model = model
        print(self.model.summary())

    def log_train_epoch(self, epoch, loss, current_best_loss, custom=""):
        if epoch % self.frequency == 0:
            print(f"{'tf_epoch'} = {epoch:6d}  elapsed = {self.__get_elapsed()}  loss = {loss:.4e}  best loss = {current_best_loss:.4e}  error = {self.__get_error_u():.4e}  " + custom)

    def log_train_opt(self, name):
        print(f"—— Starting {name} optimization ——")

    def log_train_end(self, epoch, loss, current_best_loss, custom=""):
        print("==================")
        print(f"Training finished (epoch {epoch}): duration = {self.__get_elapsed()}  loss = {loss:.4e}  best loss = {current_best_loss:.4e}  error = {self.__get_error_u():.4e}  " + custom)
        print('Applying the weights at the best epoch to the model...')


class PhysicsInformedNN(object):
    """物理信息神经网络反演模型"""
    def __init__(self, layers, optimizer, logger, ub, lb, f_param, u_param, activation_func=tf.keras.activations.tanh):
        # 建立神经网络模型 [2, 20, …, 20, 1]
        self.u_model = tf.keras.Sequential()
        self.u_model.add(tf.keras.layers.InputLayer(input_shape=(layers[0],)))
        self.u_model.add(tf.keras.layers.Lambda(
            lambda X: 2.0*(X - lb)/(ub - lb) - 1.0))
        for width in layers[1:-1]:
            self.u_model.add(tf.keras.layers.Dense(
                width, activation=activation_func,
                kernel_initializer='glorot_normal'))
        self.u_model.add(tf.keras.layers.Dense(
                layers[-1], activation=None,
                kernel_initializer='glorot_normal'))

        self.dtype = tf.float32
        self.loss_history = []
        self.l1_history = []
        self.l2_history = []
        self.f_param = f_param
        self.u_param = u_param
        self.current_best_loss = 1e10
        self.current_best_weights = []

        # 定义用于识别的两个可训练变量
        self.lambda_1 = tf.Variable([0.0], dtype=self.dtype)  # 源项位置
        self.lambda_2 = tf.Variable([2.0], dtype=self.dtype)  # 源项强度

        # 计算权重/偏置的大小，用于后续分解
        self.sizes_w = []
        self.sizes_b = []
        for i, width in enumerate(layers):
            if i != 1:
                self.sizes_w.append(int(width * layers[1]))
                self.sizes_b.append(int(width if i != 0 else layers[1]))

        self.optimizer = optimizer
        self.logger = logger

        self.beta = 0.1  # 自适应权重参数
        self.adaptive_param = 1.0
        self.adaptive_param_hat = 1.0
        self.adaptive_param_history = []

    # 物理模型 - PDE实现
    def __f_model(self, X_f):
        l1, l2 = self.get_params()
        # 分离坐标
        x_f = tf.convert_to_tensor(X_f[:, 0:1], dtype=self.dtype)
        t_f = tf.convert_to_tensor(X_f[:, 1:2], dtype=self.dtype)

        # 使用TF2.0的GradientTape计算导数
        with tf.GradientTape(persistent=True) as tape:
            tape.watch(x_f)
            tape.watch(t_f)
            X_f = tf.stack([x_f[:,0], t_f[:,0]], axis=1)

            # 获取预测
            u = self.u_model(X_f)
            # 计算空间一阶导数
            u_x = tape.gradient(u, x_f)

        # 计算其他导数
        u_xx = tape.gradient(u_x, x_f)  # 空间二阶导数
        u_t = tape.gradient(u, t_f)  # 时间导数

        del tape

        # 对流扩散方程 + 源项
        PDE = u_t + 1.0*u_x - (0.25/np.pi)*u_xx - l2*tf.exp(-100*(x_f-l1)**2)
        return PDE

    # 损失函数计算
    def __loss(self, X_u, u, u_pred):
        f_pred = self.__f_model(X_u)
        loss_f = tf.reduce_mean(tf.square(f_pred))  # PDE残差损失
        loss_u = tf.reduce_mean(tf.square(u - u_pred))  # 数据拟合损失
        return loss_u, loss_f

    # 梯度计算
    def __grad(self, X_u, u):
        with tf.GradientTape() as tape:
            loss_u, loss_f = self.__loss(X_u, u, self.u_model(X_u))
            loss_value = self.adaptive_param*loss_u + 1.0*loss_f
        return loss_value, tape.gradient(loss_value, self.__wrap_training_variables())

    # 自适应权重更新
    def __adaptive_param(self, X_u, u):
        with tf.GradientTape(persistent=True) as tape:
            loss_u, loss_f = self.__loss(X_u, u, self.u_model(X_u))
            grad_u = tape.gradient(self.adaptive_param*loss_u, self.u_model.trainable_variables)
            grad_f = tape.gradient(loss_f, self.__wrap_training_variables())
        del tape

        grad_f_flatten = []
        grad_u_flatten = []
        for g in grad_f:
            if g is not None:
                grad_f_flatten.append(tf.reshape(g, [-1]))
        grad_f_flatten = tf.concat(grad_f_flatten, 0)

        for g in grad_u:
            if g is not None:
                grad_u_flatten.append(tf.reshape(g, [-1]))
        grad_u_flatten = tf.concat(grad_u_flatten, 0)

        max_grad_f = tf.reduce_max(tf.abs(grad_f_flatten))
        mean_grad_u = tf.reduce_mean(tf.abs(grad_u_flatten))

        # 防止除零
        if mean_grad_u == 0:
            self.adaptive_param_hat = 1.0
        else:
            self.adaptive_param_hat = max_grad_f / mean_grad_u

        # 平滑更新
        self.adaptive_param = self.adaptive_param * (1.0 - self.beta) + self.beta * self.adaptive_param_hat
        self.adaptive_param_history.append(self.adaptive_param)

    # 获取所有训练变量
    def __wrap_training_variables(self):
        var = self.u_model.trainable_variables
        var.extend([self.lambda_1, self.lambda_2])
        return var

    # 为L-BFGS优化准备函数
    def get_loss_and_flat_grad(self, X_u, u):
        def loss_and_flat_grad(w):
            with tf.GradientTape() as tape:
                self.set_weights(w)
                loss_u, loss_f = self.__loss(X_u, u, self.u_model(X_u))
                loss_value = self.adaptive_param*loss_u + 1.0*loss_f
            grad = tape.gradient(loss_value, self.__wrap_training_variables())
            grad_flat = []
            for g in grad:
                if g is not None:
                    grad_flat.append(tf.reshape(g, [-1]))
            grad_flat = tf.concat(grad_flat, 0)
            return loss_value, grad_flat
        return loss_and_flat_grad

    # 获取模型权重
    def get_weights(self):
        w = []
        for layer in self.u_model.layers[1:]:
            weights_biases = layer.get_weights()
            weights = weights_biases[0].flatten()
            biases = weights_biases[1]
            w.extend(weights)
            w.extend(biases)
        w.extend(self.lambda_1.numpy())
        w.extend(self.lambda_2.numpy())
        return tf.convert_to_tensor(w, dtype=self.dtype)

    # 设置模型权重
    def set_weights(self, w):
        for i, layer in enumerate(self.u_model.layers[1:]):
            start_weights = sum(self.sizes_w[:i]) + sum(self.sizes_b[:i])
            end_weights = sum(self.sizes_w[:i+1]) + sum(self.sizes_b[:i])
            weights = w[start_weights:end_weights]
            w_div = int(self.sizes_w[i] / self.sizes_b[i])
            weights = tf.reshape(weights, [w_div, self.sizes_b[i]])
            biases = w[end_weights:end_weights + self.sizes_b[i]]
            weights_biases = [weights, biases]
            layer.set_weights(weights_biases)
        self.lambda_1.assign([w[-2]])
        self.lambda_2.assign([w[-1]])

    # 获取当前参数值
    def get_params(self, numpy=False):
        l1 = self.lambda_1
        l2 = self.lambda_2
        if numpy:
            return l1.numpy()[0], l2.numpy()[0]
        return l1, l2

    # 打印模型摘要
    def summary(self):
        return self.u_model.summary()

    # 小批量采样
    def mini_batch(self, X_u, u, batch_size):
        idx_u = np.random.randint(0, tf.shape(X_u).numpy()[0], batch_size)
        X_u_batch = tf.gather(X_u, idx_u)
        u_batch = tf.gather(u, idx_u)
        return X_u_batch, u_batch

    # L-BFGS回调函数
    def lbfgs_callback(self, weights, X_u, u):
        """每次L-BFGS迭代后更新历史记录"""
        self.set_weights(weights)
        current_l1, current_l2 = self.get_params(numpy=True)

        # 记录当前参数值
        global callback_lbfgs_l1s, callback_lbfgs_l2s
        callback_lbfgs_l1s.append(current_l1)
        callback_lbfgs_l2s.append(current_l2)

        # 每10次迭代输出一次
        if len(callback_lbfgs_l1s) % 10 == 0:
            print(f"L-BFGS step {len(callback_lbfgs_l1s)}: l1 = {current_l1:.6f}, l2 = {current_l2:.6f}")

        return False  # 返回False继续优化

    # 训练函数
    def fit(self, X_u, u, tf_epochs, batch_size=512):
        global callback_lbfgs_iterations, callback_lbfgs_losses, callback_lbfgs_l1s, callback_lbfgs_l2s
        self.logger.log_train_start(self)

        # 转换为张量
        X_u = tf.convert_to_tensor(X_u, dtype=self.dtype)
        u = tf.convert_to_tensor(u, dtype=self.dtype)

        iter_per_epoch = int(np.floor(tf.shape(X_u).numpy()[0]/batch_size))

        def log_train_epoch(epoch, loss):
            l1, l2 = self.get_params(numpy=True)
            custom = f"l1 = {l1:4f} l2 = {l2:4f} adaptive_param = {self.adaptive_param:4f}"
            self.logger.log_train_epoch(epoch, loss, self.current_best_loss, custom)

        # ADAM优化
        self.logger.log_train_opt("Adam")
        for epoch in range(tf_epochs):
            for index in range(iter_per_epoch):
                X_u_batch, u_batch = self.mini_batch(X_u, u, batch_size)

                # 取消注释以启用自适应权重
                # self.__adaptive_param(X_u_batch, u_batch)

                # 优化步骤
                loss_value, grads = self.__grad(X_u_batch, u_batch)
                self.optimizer.apply_gradients(zip(grads, self.__wrap_training_variables()))

            # 在完整数据集上计算损失
            loss_u, loss_f = self.__loss(X_u, u, self.u_model(X_u))
            loss_value = self.adaptive_param*loss_u + 1.0*loss_f

            if loss_value < self.current_best_loss:
              self.current_best_loss = loss_value
              self.current_best_weights = self.get_weights()

            log_train_epoch(epoch, loss_value)

            # 记录历史
            self.loss_history.append(loss_value.numpy())
            l1, l2 = self.get_params(numpy=True)
            self.l1_history.append(l1)
            self.l2_history.append(l2)

        # 重置回调变量
        callback_lbfgs_iterations = []
        callback_lbfgs_losses = []
        callback_lbfgs_l1s = []
        callback_lbfgs_l2s = []

        # L-BFGS优化
        print("Starting L-BFGS training")

        # 存储ADAM优化后的参数
        adam_l1, adam_l2 = self.get_params(numpy=True)
        print(f"Parameters after ADAM: l1 = {adam_l1:.6f}, l2 = {adam_l2:.6f}")

        # 准备优化函数
        loss_and_flat_grad = self.get_loss_and_flat_grad(X_u, u)

        # 定义L-BFGS回调函数的闭包
        def callback_lbfgs_wrapper(xk):
            return self.lbfgs_callback(xk, X_u, u)

        # 运行L-BFGS优化
        lbfgs_weights, lbfgs_history, _ = lbfgs(
            loss_and_flat_grad,
            self.get_weights(),
            Struct(),
            maxIter=500,
            learningRate=0.8,
            do_verbose=False,  # 使用自定义日志
            callback=callback_lbfgs_wrapper  # 传递回调函数
        )

        # 应用最终权重
        self.set_weights(lbfgs_weights)

        # 检查L-BFGS是否改进了解决方案
        final_loss_u, final_loss_f = self.__loss(X_u, u, self.u_model(X_u))
        final_loss = self.adaptive_param*final_loss_u + 1.0*final_loss_f

        if final_loss < self.current_best_loss:
            self.current_best_loss = final_loss
            self.current_best_weights = lbfgs_weights

        # 将L-BFGS历史添加到总体历史
        for i in range(len(callback_lbfgs_losses)):
            self.loss_history.append(callback_lbfgs_losses[i])
            self.l1_history.append(callback_lbfgs_l1s[i])
            self.l2_history.append(callback_lbfgs_l2s[i])

        # 设置最佳权重
        self.set_weights(self.current_best_weights)
        final_l1, final_l2 = self.get_params(numpy=True)

        self.logger.log_train_end(
            tf_epochs,
            final_loss,
            self.current_best_loss,
            f"l1 = {final_l1:.6f}, l2 = {final_l2:.6f}"
        )

        return self.loss_history, self.l1_history, self.l2_history, self.adaptive_param_history

    # 预测函数
    def predict(self, X_star):
        u_star = self.u_model(X_star)
        f_star = self.__f_model(X_star)
        return u_star.numpy(), f_star.numpy()


# 定义误差计算函数
def error():
    """计算参数反演的相对误差"""
    l1, l2 = pinn.get_params(numpy=True)
    l1_star, l2_star = lambdas_star
    error_lambda_1 = np.abs(l1 - l1_star) / np.abs(l1_star)
    error_lambda_2 = np.abs(l2 - l2_star) / np.abs(l2_star)
    return (error_lambda_1 + error_lambda_2) / 2


# 主程序执行部分
if __name__ == "__main__":
    # 设置参数
    N_u = 5000  # 数据点数量
    layers = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]  # 神经网络层大小
    activation_func = tf.keras.activations.tanh  # 激活函数

    # ADAM优化器设置
    tf_epochs = 100  # ADAM优化轮数
    tf_optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
    batch_size = 5000  # 批量大小

    # 损失函数权重
    f_param = 1  # PDE损失权重
    u_param = 1  # 数据拟合损失权重

    # 真实参数值
    lambdas_star = (-0.8, 5.0)  # 源项位置、强度

    # 边界条件设置
    inc_bounds = True  # 是否包含边界条件
    ICBC =  1 # 边界条件点数量
    noise = 0.1  # 噪声水平

    # 加载数据
    path = "1D_ADE_Training_Data.mat"  # 数据文件路径
    x, t, X, T, X_star, u_star, X_u_train, u_train, ub, lb = prep_data_dense(path, N_u, noise, inc_bounds, ICBC)

    # 可视化训练数据
    TrainingDataPlotter(X_u_train, ub, lb)

    # 创建模型并训练
    logger = Logger(frequency=1)
    logger.set_error_fn(error)
    pinn = PhysicsInformedNN(layers, tf_optimizer, logger, ub, lb, f_param, u_param, activation_func)

    # 训练模型
    loss_history, l1_history, l2_history, adaptive_param_history = pinn.fit(X_u_train, u_train, tf_epochs, batch_size)

    # 绘制损失和参数历史
    LossParameterPlotter(loss_history, l1_history, l2_history)

    # 提取数据并可视化结果
    u_star_plot, u_plot, u_train_pred, trained_weights = ExtractData(pinn, X_star, X_u_train, u_star)
    DiscretePlotter(x, t, u_plot, u_star_plot, lb, ub)

    # 保存结果
    savemat('PINNresults1DInverse.mat', {
        'u_pred': u_plot,
        'u_true': u_star_plot,
        'loss_history': loss_history,
        'l1_history': l1_history,
        'l2_history': l2_history,
        'adaptive_param_history': adaptive_param_history,
        'X_u_train': X_u_train,
        'u_train': u_train,
        'u_train_pred': u_train_pred,
        'X': X,
        'T': T,
        'X_star': X_star,
        'x': x,
        't': t,
        'layers': layers,
        'noise': noise,
        'u_param': u_param,
        'f_param': f_param
    })

    # 输出最终参数
    final_l1, final_l2 = pinn.get_params(numpy=True)
    print(f"\nFinal Parameters:")
    print(f"Source Position (l1): {final_l1:.6f} (True: {lambdas_star[0]})")
    print(f"Source Strength (l2): {final_l2:.6f} (True: {lambdas_star[1]})")
    print(f"Relative Error: {error():.6f}")
# Out:
# Amount of training data: 5001
# TensorFlow version: 2.18.0
# Eager execution: True
# GPU-accerelated: False
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Training started
# ================
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lambda_1 (Lambda)                    │ (None, 2)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 20)                  │              60 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 20)                  │             420 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 20)                  │             420 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 20)                  │             420 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 20)                  │             420 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 20)                  │             420 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 20)                  │             420 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 20)                  │             420 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 1)                   │              21 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,021 (11.80 KB)
#  Trainable params: 3,021 (11.80 KB)
#  Non-trainable params: 0 (0.00 B)
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# None
# —— Starting Adam optimization ——
# tf_epoch =      0  elapsed = 00:00:01  loss = 1.3882e+00  best loss = 1.3882e+00  error = 7.9948e-01  l1 = -0.001000 l2 = 1.999000 adaptive_param = 1.000000
# tf_epoch =      1  elapsed = 00:00:01  loss = 8.6489e-01  best loss = 8.6489e-01  error = 8.0001e-01  l1 = -0.000309 l2 = 1.998007 adaptive_param = 1.000000
# tf_epoch =      2  elapsed = 00:00:02  loss = 5.3885e-01  best loss = 5.3885e-01  error = 8.0046e-01  l1 = 0.000257 l2 = 1.997025 adaptive_param = 1.000000
# tf_epoch =      3  elapsed = 00:00:02  loss = 3.6847e-01  best loss = 3.6847e-01  error = 8.0082e-01  l1 = 0.000674 l2 = 1.996054 adaptive_param = 1.000000
# tf_epoch =      4  elapsed = 00:00:03  loss = 3.1167e-01  best loss = 3.1167e-01  error = 8.0089e-01  l1 = 0.000647 l2 = 1.995106 adaptive_param = 1.000000
# tf_epoch =      5  elapsed = 00:00:04  loss = 3.2585e-01  best loss = 3.1167e-01  error = 8.0074e-01  l1 = 0.000258 l2 = 1.994177 adaptive_param = 1.000000
# tf_epoch =      6  elapsed = 00:00:04  loss = 3.7013e-01  best loss = 3.1167e-01  error = 8.0053e-01  l1 = -0.000234 l2 = 1.993276 adaptive_param = 1.000000
# tf_epoch =      7  elapsed = 00:00:05  loss = 4.1260e-01  best loss = 3.1167e-01  error = 8.0027e-01  l1 = -0.000786 l2 = 1.992408 adaptive_param = 1.000000
# tf_epoch =      8  elapsed = 00:00:06  loss = 4.3626e-01  best loss = 3.1167e-01  error = 7.9999e-01  l1 = -0.001361 l2 = 1.991574 adaptive_param = 1.000000
# tf_epoch =      9  elapsed = 00:00:06  loss = 4.3777e-01  best loss = 3.1167e-01  error = 7.9971e-01  l1 = -0.001943 l2 = 1.990769 adaptive_param = 1.000000
# tf_epoch =     10  elapsed = 00:00:07  loss = 4.2072e-01  best loss = 3.1167e-01  error = 7.9939e-01  l1 = -0.002584 l2 = 1.989989 adaptive_param = 1.000000
# tf_epoch =     11  elapsed = 00:00:08  loss = 3.9204e-01  best loss = 3.1167e-01  error = 7.9907e-01  l1 = -0.003210 l2 = 1.989233 adaptive_param = 1.000000
# tf_epoch =     12  elapsed = 00:00:08  loss = 3.5895e-01  best loss = 3.1167e-01  error = 7.9878e-01  l1 = -0.003791 l2 = 1.988491 adaptive_param = 1.000000
# tf_epoch =     13  elapsed = 00:00:09  loss = 3.2682e-01  best loss = 3.1167e-01  error = 7.9850e-01  l1 = -0.004354 l2 = 1.987762 adaptive_param = 1.000000
# tf_epoch =     14  elapsed = 00:00:09  loss = 2.9941e-01  best loss = 2.9941e-01  error = 7.9819e-01  l1 = -0.004968 l2 = 1.987038 adaptive_param = 1.000000
# tf_epoch =     15  elapsed = 00:00:10  loss = 2.7835e-01  best loss = 2.7835e-01  error = 7.9792e-01  l1 = -0.005525 l2 = 1.986319 adaptive_param = 1.000000
# tf_epoch =     16  elapsed = 00:00:10  loss = 2.6424e-01  best loss = 2.6424e-01  error = 7.9766e-01  l1 = -0.006042 l2 = 1.985595 adaptive_param = 1.000000
# tf_epoch =     17  elapsed = 00:00:11  loss = 2.5643e-01  best loss = 2.5643e-01  error = 7.9745e-01  l1 = -0.006507 l2 = 1.984864 adaptive_param = 1.000000
# tf_epoch =     18  elapsed = 00:00:12  loss = 2.5368e-01  best loss = 2.5368e-01  error = 7.9724e-01  l1 = -0.006961 l2 = 1.984121 adaptive_param = 1.000000
# tf_epoch =     19  elapsed = 00:00:12  loss = 2.5444e-01  best loss = 2.5368e-01  error = 7.9703e-01  l1 = -0.007413 l2 = 1.983363 adaptive_param = 1.000000
# tf_epoch =     20  elapsed = 00:00:13  loss = 2.5708e-01  best loss = 2.5368e-01  error = 7.9684e-01  l1 = -0.007835 l2 = 1.982583 adaptive_param = 1.000000
# tf_epoch =     21  elapsed = 00:00:13  loss = 2.6034e-01  best loss = 2.5368e-01  error = 7.9673e-01  l1 = -0.008145 l2 = 1.981790 adaptive_param = 1.000000
# tf_epoch =     22  elapsed = 00:00:14  loss = 2.6313e-01  best loss = 2.5368e-01  error = 7.9660e-01  l1 = -0.008476 l2 = 1.980981 adaptive_param = 1.000000
# tf_epoch =     23  elapsed = 00:00:14  loss = 2.6476e-01  best loss = 2.5368e-01  error = 7.9648e-01  l1 = -0.008813 l2 = 1.980153 adaptive_param = 1.000000
# tf_epoch =     24  elapsed = 00:00:15  loss = 2.6489e-01  best loss = 2.5368e-01  error = 7.9637e-01  l1 = -0.009115 l2 = 1.979311 adaptive_param = 1.000000
# tf_epoch =     25  elapsed = 00:00:15  loss = 2.6365e-01  best loss = 2.5368e-01  error = 7.9629e-01  l1 = -0.009385 l2 = 1.978461 adaptive_param = 1.000000
# tf_epoch =     26  elapsed = 00:00:16  loss = 2.6113e-01  best loss = 2.5368e-01  error = 7.9619e-01  l1 = -0.009677 l2 = 1.977601 adaptive_param = 1.000000
# tf_epoch =     27  elapsed = 00:00:16  loss = 2.5764e-01  best loss = 2.5368e-01  error = 7.9607e-01  l1 = -0.010014 l2 = 1.976732 adaptive_param = 1.000000
# tf_epoch =     28  elapsed = 00:00:17  loss = 2.5350e-01  best loss = 2.5350e-01  error = 7.9591e-01  l1 = -0.010403 l2 = 1.975855 adaptive_param = 1.000000
# tf_epoch =     29  elapsed = 00:00:17  loss = 2.4903e-01  best loss = 2.4903e-01  error = 7.9576e-01  l1 = -0.010782 l2 = 1.974969 adaptive_param = 1.000000
# tf_epoch =     30  elapsed = 00:00:18  loss = 2.4451e-01  best loss = 2.4451e-01  error = 7.9564e-01  l1 = -0.011118 l2 = 1.974072 adaptive_param = 1.000000
# tf_epoch =     31  elapsed = 00:00:19  loss = 2.4019e-01  best loss = 2.4019e-01  error = 7.9555e-01  l1 = -0.011421 l2 = 1.973167 adaptive_param = 1.000000
# tf_epoch =     32  elapsed = 00:00:20  loss = 2.3631e-01  best loss = 2.3631e-01  error = 7.9551e-01  l1 = -0.011627 l2 = 1.972258 adaptive_param = 1.000000
# tf_epoch =     33  elapsed = 00:00:20  loss = 2.3298e-01  best loss = 2.3298e-01  error = 7.9552e-01  l1 = -0.011750 l2 = 1.971346 adaptive_param = 1.000000
# tf_epoch =     34  elapsed = 00:00:21  loss = 2.3025e-01  best loss = 2.3025e-01  error = 7.9557e-01  l1 = -0.011822 l2 = 1.970431 adaptive_param = 1.000000
# tf_epoch =     35  elapsed = 00:00:22  loss = 2.2810e-01  best loss = 2.2810e-01  error = 7.9558e-01  l1 = -0.011952 l2 = 1.969519 adaptive_param = 1.000000
# tf_epoch =     36  elapsed = 00:00:22  loss = 2.2649e-01  best loss = 2.2649e-01  error = 7.9562e-01  l1 = -0.012029 l2 = 1.968609 adaptive_param = 1.000000
# tf_epoch =     37  elapsed = 00:00:23  loss = 2.2532e-01  best loss = 2.2532e-01  error = 7.9569e-01  l1 = -0.012068 l2 = 1.967703 adaptive_param = 1.000000
# tf_epoch =     38  elapsed = 00:00:23  loss = 2.2447e-01  best loss = 2.2447e-01  error = 7.9573e-01  l1 = -0.012149 l2 = 1.966796 adaptive_param = 1.000000
# tf_epoch =     39  elapsed = 00:00:24  loss = 2.2382e-01  best loss = 2.2382e-01  error = 7.9570e-01  l1 = -0.012333 l2 = 1.965893 adaptive_param = 1.000000
# tf_epoch =     40  elapsed = 00:00:24  loss = 2.2329e-01  best loss = 2.2329e-01  error = 7.9577e-01  l1 = -0.012375 l2 = 1.964994 adaptive_param = 1.000000
# tf_epoch =     41  elapsed = 00:00:25  loss = 2.2276e-01  best loss = 2.2276e-01  error = 7.9582e-01  l1 = -0.012430 l2 = 1.964096 adaptive_param = 1.000000
# tf_epoch =     42  elapsed = 00:00:25  loss = 2.2216e-01  best loss = 2.2216e-01  error = 7.9591e-01  l1 = -0.012430 l2 = 1.963204 adaptive_param = 1.000000
# tf_epoch =     43  elapsed = 00:00:26  loss = 2.2144e-01  best loss = 2.2144e-01  error = 7.9601e-01  l1 = -0.012408 l2 = 1.962315 adaptive_param = 1.000000
# tf_epoch =     44  elapsed = 00:00:26  loss = 2.2056e-01  best loss = 2.2056e-01  error = 7.9617e-01  l1 = -0.012304 l2 = 1.961430 adaptive_param = 1.000000
# tf_epoch =     45  elapsed = 00:00:27  loss = 2.1952e-01  best loss = 2.1952e-01  error = 7.9626e-01  l1 = -0.012297 l2 = 1.960546 adaptive_param = 1.000000
# tf_epoch =     46  elapsed = 00:00:27  loss = 2.1835e-01  best loss = 2.1835e-01  error = 7.9637e-01  l1 = -0.012268 l2 = 1.959660 adaptive_param = 1.000000
# tf_epoch =     47  elapsed = 00:00:28  loss = 2.1704e-01  best loss = 2.1704e-01  error = 7.9638e-01  l1 = -0.012387 l2 = 1.958785 adaptive_param = 1.000000
# tf_epoch =     48  elapsed = 00:00:28  loss = 2.1565e-01  best loss = 2.1565e-01  error = 7.9640e-01  l1 = -0.012498 l2 = 1.957905 adaptive_param = 1.000000
# tf_epoch =     49  elapsed = 00:00:29  loss = 2.1421e-01  best loss = 2.1421e-01  error = 7.9643e-01  l1 = -0.012583 l2 = 1.957030 adaptive_param = 1.000000
# tf_epoch =     50  elapsed = 00:00:29  loss = 2.1274e-01  best loss = 2.1274e-01  error = 7.9644e-01  l1 = -0.012711 l2 = 1.956153 adaptive_param = 1.000000
# tf_epoch =     51  elapsed = 00:00:30  loss = 2.1129e-01  best loss = 2.1129e-01  error = 7.9653e-01  l1 = -0.012706 l2 = 1.955274 adaptive_param = 1.000000
# tf_epoch =     52  elapsed = 00:00:30  loss = 2.0984e-01  best loss = 2.0984e-01  error = 7.9665e-01  l1 = -0.012659 l2 = 1.954397 adaptive_param = 1.000000
# tf_epoch =     53  elapsed = 00:00:31  loss = 2.0842e-01  best loss = 2.0842e-01  error = 7.9677e-01  l1 = -0.012612 l2 = 1.953521 adaptive_param = 1.000000
# tf_epoch =     54  elapsed = 00:00:32  loss = 2.0704e-01  best loss = 2.0704e-01  error = 7.9696e-01  l1 = -0.012440 l2 = 1.952644 adaptive_param = 1.000000
# tf_epoch =     55  elapsed = 00:00:32  loss = 2.0566e-01  best loss = 2.0566e-01  error = 7.9707e-01  l1 = -0.012402 l2 = 1.951759 adaptive_param = 1.000000
# tf_epoch =     56  elapsed = 00:00:33  loss = 2.0429e-01  best loss = 2.0429e-01  error = 7.9720e-01  l1 = -0.012345 l2 = 1.950878 adaptive_param = 1.000000
# tf_epoch =     57  elapsed = 00:00:34  loss = 2.0291e-01  best loss = 2.0291e-01  error = 7.9729e-01  l1 = -0.012343 l2 = 1.949997 adaptive_param = 1.000000
# tf_epoch =     58  elapsed = 00:00:35  loss = 2.0151e-01  best loss = 2.0151e-01  error = 7.9741e-01  l1 = -0.012284 l2 = 1.949113 adaptive_param = 1.000000
# tf_epoch =     59  elapsed = 00:00:35  loss = 2.0008e-01  best loss = 2.0008e-01  error = 7.9755e-01  l1 = -0.012211 l2 = 1.948227 adaptive_param = 1.000000
# tf_epoch =     60  elapsed = 00:00:36  loss = 1.9862e-01  best loss = 1.9862e-01  error = 7.9766e-01  l1 = -0.012163 l2 = 1.947343 adaptive_param = 1.000000
# tf_epoch =     61  elapsed = 00:00:36  loss = 1.9713e-01  best loss = 1.9713e-01  error = 7.9785e-01  l1 = -0.012007 l2 = 1.946460 adaptive_param = 1.000000
# tf_epoch =     62  elapsed = 00:00:37  loss = 1.9560e-01  best loss = 1.9560e-01  error = 7.9798e-01  l1 = -0.011946 l2 = 1.945576 adaptive_param = 1.000000
# tf_epoch =     63  elapsed = 00:00:37  loss = 1.9405e-01  best loss = 1.9405e-01  error = 7.9814e-01  l1 = -0.011823 l2 = 1.944694 adaptive_param = 1.000000
# tf_epoch =     64  elapsed = 00:00:38  loss = 1.9250e-01  best loss = 1.9250e-01  error = 7.9828e-01  l1 = -0.011736 l2 = 1.943818 adaptive_param = 1.000000
# tf_epoch =     65  elapsed = 00:00:38  loss = 1.9094e-01  best loss = 1.9094e-01  error = 7.9840e-01  l1 = -0.011681 l2 = 1.942945 adaptive_param = 1.000000
# tf_epoch =     66  elapsed = 00:00:39  loss = 1.8935e-01  best loss = 1.8935e-01  error = 7.9849e-01  l1 = -0.011692 l2 = 1.942070 adaptive_param = 1.000000
# tf_epoch =     67  elapsed = 00:00:39  loss = 1.8773e-01  best loss = 1.8773e-01  error = 7.9859e-01  l1 = -0.011669 l2 = 1.941192 adaptive_param = 1.000000
# tf_epoch =     68  elapsed = 00:00:40  loss = 1.8610e-01  best loss = 1.8610e-01  error = 7.9874e-01  l1 = -0.011559 l2 = 1.940321 adaptive_param = 1.000000
# tf_epoch =     69  elapsed = 00:00:40  loss = 1.8445e-01  best loss = 1.8445e-01  error = 7.9881e-01  l1 = -0.011593 l2 = 1.939459 adaptive_param = 1.000000
# tf_epoch =     70  elapsed = 00:00:41  loss = 1.8276e-01  best loss = 1.8276e-01  error = 7.9884e-01  l1 = -0.011682 l2 = 1.938595 adaptive_param = 1.000000
# tf_epoch =     71  elapsed = 00:00:41  loss = 1.8102e-01  best loss = 1.8102e-01  error = 7.9888e-01  l1 = -0.011760 l2 = 1.937740 adaptive_param = 1.000000
# tf_epoch =     72  elapsed = 00:00:42  loss = 1.7924e-01  best loss = 1.7924e-01  error = 7.9898e-01  l1 = -0.011738 l2 = 1.936886 adaptive_param = 1.000000
# tf_epoch =     73  elapsed = 00:00:42  loss = 1.7740e-01  best loss = 1.7740e-01  error = 7.9905e-01  l1 = -0.011759 l2 = 1.936042 adaptive_param = 1.000000
# tf_epoch =     74  elapsed = 00:00:43  loss = 1.7551e-01  best loss = 1.7551e-01  error = 7.9904e-01  l1 = -0.011898 l2 = 1.935206 adaptive_param = 1.000000
# tf_epoch =     75  elapsed = 00:00:43  loss = 1.7355e-01  best loss = 1.7355e-01  error = 7.9904e-01  l1 = -0.012040 l2 = 1.934375 adaptive_param = 1.000000
# tf_epoch =     76  elapsed = 00:00:44  loss = 1.7154e-01  best loss = 1.7154e-01  error = 7.9893e-01  l1 = -0.012346 l2 = 1.933551 adaptive_param = 1.000000
# tf_epoch =     77  elapsed = 00:00:45  loss = 1.6947e-01  best loss = 1.6947e-01  error = 7.9879e-01  l1 = -0.012705 l2 = 1.932731 adaptive_param = 1.000000
# tf_epoch =     78  elapsed = 00:00:45  loss = 1.6736e-01  best loss = 1.6736e-01  error = 7.9872e-01  l1 = -0.012948 l2 = 1.931917 adaptive_param = 1.000000
# tf_epoch =     79  elapsed = 00:00:46  loss = 1.6521e-01  best loss = 1.6521e-01  error = 7.9859e-01  l1 = -0.013279 l2 = 1.931113 adaptive_param = 1.000000
# tf_epoch =     80  elapsed = 00:00:47  loss = 1.6301e-01  best loss = 1.6301e-01  error = 7.9847e-01  l1 = -0.013599 l2 = 1.930317 adaptive_param = 1.000000
# tf_epoch =     81  elapsed = 00:00:48  loss = 1.6078e-01  best loss = 1.6078e-01  error = 7.9836e-01  l1 = -0.013903 l2 = 1.929530 adaptive_param = 1.000000
# tf_epoch =     82  elapsed = 00:00:48  loss = 1.5847e-01  best loss = 1.5847e-01  error = 7.9827e-01  l1 = -0.014177 l2 = 1.928746 adaptive_param = 1.000000
# tf_epoch =     83  elapsed = 00:00:49  loss = 1.5609e-01  best loss = 1.5609e-01  error = 7.9817e-01  l1 = -0.014460 l2 = 1.927971 adaptive_param = 1.000000
# tf_epoch =     84  elapsed = 00:00:49  loss = 1.5366e-01  best loss = 1.5366e-01  error = 7.9804e-01  l1 = -0.014779 l2 = 1.927205 adaptive_param = 1.000000
# tf_epoch =     85  elapsed = 00:00:50  loss = 1.5113e-01  best loss = 1.5113e-01  error = 7.9796e-01  l1 = -0.015027 l2 = 1.926446 adaptive_param = 1.000000
# tf_epoch =     86  elapsed = 00:00:50  loss = 1.4852e-01  best loss = 1.4852e-01  error = 7.9795e-01  l1 = -0.015167 l2 = 1.925696 adaptive_param = 1.000000
# tf_epoch =     87  elapsed = 00:00:51  loss = 1.4580e-01  best loss = 1.4580e-01  error = 7.9792e-01  l1 = -0.015329 l2 = 1.924952 adaptive_param = 1.000000
# tf_epoch =     88  elapsed = 00:00:51  loss = 1.4292e-01  best loss = 1.4292e-01  error = 7.9795e-01  l1 = -0.015403 l2 = 1.924211 adaptive_param = 1.000000
# tf_epoch =     89  elapsed = 00:00:52  loss = 1.3990e-01  best loss = 1.3990e-01  error = 7.9798e-01  l1 = -0.015474 l2 = 1.923473 adaptive_param = 1.000000
# tf_epoch =     90  elapsed = 00:00:52  loss = 1.3670e-01  best loss = 1.3670e-01  error = 7.9803e-01  l1 = -0.015519 l2 = 1.922733 adaptive_param = 1.000000
# tf_epoch =     91  elapsed = 00:00:53  loss = 1.3338e-01  best loss = 1.3338e-01  error = 7.9814e-01  l1 = -0.015461 l2 = 1.922000 adaptive_param = 1.000000
# tf_epoch =     92  elapsed = 00:00:53  loss = 1.2995e-01  best loss = 1.2995e-01  error = 7.9829e-01  l1 = -0.015327 l2 = 1.921280 adaptive_param = 1.000000
# tf_epoch =     93  elapsed = 00:00:54  loss = 1.2640e-01  best loss = 1.2640e-01  error = 7.9849e-01  l1 = -0.015123 l2 = 1.920577 adaptive_param = 1.000000
# tf_epoch =     94  elapsed = 00:00:55  loss = 1.2268e-01  best loss = 1.2268e-01  error = 7.9869e-01  l1 = -0.014912 l2 = 1.919883 adaptive_param = 1.000000
# tf_epoch =     95  elapsed = 00:00:55  loss = 1.1881e-01  best loss = 1.1881e-01  error = 7.9891e-01  l1 = -0.014677 l2 = 1.919204 adaptive_param = 1.000000
# tf_epoch =     96  elapsed = 00:00:56  loss = 1.1479e-01  best loss = 1.1479e-01  error = 7.9908e-01  l1 = -0.014497 l2 = 1.918544 adaptive_param = 1.000000
# tf_epoch =     97  elapsed = 00:00:56  loss = 1.1057e-01  best loss = 1.1057e-01  error = 7.9928e-01  l1 = -0.014296 l2 = 1.917894 adaptive_param = 1.000000
# tf_epoch =     98  elapsed = 00:00:57  loss = 1.0619e-01  best loss = 1.0619e-01  error = 7.9945e-01  l1 = -0.014115 l2 = 1.917258 adaptive_param = 1.000000
# tf_epoch =     99  elapsed = 00:00:57  loss = 1.0167e-01  best loss = 1.0167e-01  error = 7.9961e-01  l1 = -0.013965 l2 = 1.916639 adaptive_param = 1.000000
# Starting L-BFGS training
# Parameters after ADAM: l1 = -0.013965, l2 = 1.916639
# L-BFGS step 10: l1 = 0.010118, l2 = 1.872705
# L-BFGS step 20: l1 = -0.064286, l2 = 1.666101
# L-BFGS step 30: l1 = -0.109225, l2 = 1.588089
# L-BFGS step 40: l1 = -0.238324, l2 = 1.360759
# L-BFGS step 50: l1 = -0.520255, l2 = 0.942051
# L-BFGS step 60: l1 = -0.672419, l2 = 0.801807
# L-BFGS step 70: l1 = -0.713032, l2 = 1.096111
# L-BFGS step 80: l1 = -0.747319, l2 = 1.381805
# L-BFGS step 90: l1 = -0.757926, l2 = 1.922587
# L-BFGS step 100: l1 = -0.768740, l2 = 2.360792
# L-BFGS step 110: l1 = -0.763037, l2 = 2.500871
# L-BFGS step 120: l1 = -0.769943, l2 = 2.961390
# L-BFGS step 130: l1 = -0.776866, l2 = 3.172601
# L-BFGS step 140: l1 = -0.776826, l2 = 3.605410
# L-BFGS step 150: l1 = -0.784451, l2 = 3.841193
# L-BFGS step 160: l1 = -0.795924, l2 = 4.304244
# L-BFGS step 170: l1 = -0.795694, l2 = 4.325662
# L-BFGS step 180: l1 = -0.800702, l2 = 4.553739
# L-BFGS step 190: l1 = -0.794935, l2 = 4.535489
# L-BFGS step 200: l1 = -0.800356, l2 = 4.681481
# L-BFGS step 210: l1 = -0.798547, l2 = 4.635991
# L-BFGS step 220: l1 = -0.797690, l2 = 4.671302
# L-BFGS step 230: l1 = -0.800093, l2 = 4.658944
# L-BFGS step 240: l1 = -0.802435, l2 = 4.750636
# L-BFGS step 250: l1 = -0.805301, l2 = 4.821977
# L-BFGS step 260: l1 = -0.803021, l2 = 4.791207
# L-BFGS step 270: l1 = -0.806254, l2 = 4.826500
# L-BFGS step 280: l1 = -0.806773, l2 = 4.884541
# L-BFGS step 290: l1 = -0.807067, l2 = 4.930130
# L-BFGS step 300: l1 = -0.804689, l2 = 4.862939
# L-BFGS step 310: l1 = -0.803711, l2 = 4.871248
# L-BFGS step 320: l1 = -0.804666, l2 = 4.908397
# L-BFGS step 330: l1 = -0.803027, l2 = 4.882148
# L-BFGS step 340: l1 = -0.802655, l2 = 4.920589
# L-BFGS step 350: l1 = -0.803348, l2 = 4.999712
# L-BFGS step 360: l1 = -0.804581, l2 = 4.973121
# L-BFGS step 370: l1 = -0.805925, l2 = 5.016637
# L-BFGS step 380: l1 = -0.804208, l2 = 4.970372
# L-BFGS step 390: l1 = -0.802883, l2 = 4.938440
# L-BFGS step 400: l1 = -0.802516, l2 = 4.911631
# L-BFGS step 410: l1 = -0.803463, l2 = 4.905086
# L-BFGS step 420: l1 = -0.801369, l2 = 4.887789
# L-BFGS step 430: l1 = -0.803344, l2 = 4.940394
# L-BFGS step 440: l1 = -0.803124, l2 = 4.939125
# L-BFGS step 450: l1 = -0.802054, l2 = 4.904066
# L-BFGS step 460: l1 = -0.801212, l2 = 4.890863
# L-BFGS step 470: l1 = -0.802428, l2 = 4.891145
# L-BFGS step 480: l1 = -0.801840, l2 = 4.869363
# L-BFGS step 490: l1 = -0.801852, l2 = 4.903816
# L-BFGS step 500: l1 = -0.801387, l2 = 4.919467
# ==================
# Training finished (epoch 100): duration = 00:04:38  loss = 8.4510e-04  best loss = 8.4510e-04  error = 8.8254e-03  l1 = -0.801601, l2 = 4.921752
# Applying the weights at the best epoch to the model...
# Final Parameters:
# Source Position (l1): -0.801601 (True: -0.8)
# Source Strength (l2): 4.921752 (True: 5.0)
# Relative Error: 0.008825
